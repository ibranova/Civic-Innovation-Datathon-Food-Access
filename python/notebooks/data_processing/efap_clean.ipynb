# %% [markdown]
# ## Key assumption
# We assume that the EFAP food assistance site landscape remained largely stable between 2023 and 2024, and therefore use the November 4, 2024 EFAP dataset as a proxy for food assistance site availability across both years of analysis.
#
# ## key limitation
# Because EFAP data are only available as point-in-time snapshots, this approach does not capture potential changes in site availability between 2023 and 2024, such as temporary closures, relocations, or newly established programs. As a result, supply measures may not reflect short-term fluctuations in food assistance access over time.

# %%
import pandas as pd 
import requests
import os
import re

# %%
df = pd.read_csv('EFAP_pdf_11_4_24.csv')

# %%
df.head()
# Out:
#       ID TYPE                                   PROGRAM         PHONE  \
# 0  80604   SK               HOLY APOSTLES SOUP KITCHEN   212 924-0167
# 1  85547   FP        HOLY APOSTLES SOUP KITCHEN PANTRY   646-998-6105
# 2  80757   FP                 ST. JOHN'S BREAD OF LIFE   212 564-9070
# 3  85701   FP  ARTISTS ATHLETES ACTIVISTS INCORPORATED   347-229-8399
# 4  80546   FP                   DEWITT REFORMED CHURCH   212 674-3341
#
#                 DISTADD DISTBORO  DISTZIP                     DAYS
# 0      296 NINTH AVENUE       NY    10001  MON-FRI 10:30AM-12:30PM
# 1      296 NINTH AVENUE       NY    10001    TUE,WED,THUR 1:30-3PM
# 2  213 WEST 30TH STREET       NY    10001       WED (2,4) 11AM-1PM
# 3   110 COLUMBIA STREET       NY    10002           THUR 12:30-3PM
# 4  280 RIVINGTON STREET       NY    10002       SAT(1,3) 10AM-12PM

# %% [markdown]
# ### Clean the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        561 non-null    int64
#  1   TYPE      561 non-null    object
#  2   PROGRAM   561 non-null    object
#  3   PHONE     561 non-null    object
#  4   DISTADD   561 non-null    object
#  5   DISTBORO  560 non-null    object
#  6   DISTZIP   561 non-null    int64
#  7   DAYS      561 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 35.2+ KB

# %%
df.isnull().sum()
# Out:
# ID          0
# TYPE        0
# PROGRAM     0
# PHONE       0
# DISTADD     0
# DISTBORO    1
# DISTZIP     0
# DAYS        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# check if rows are duplicted too
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, TYPE, PROGRAM, PHONE, DISTADD, DISTBORO, DISTZIP, DAYS]
# Index: []

# %%
df.keys()
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'PHONE', 'DISTADD', 'DISTBORO', 'DISTZIP',
#        'DAYS'],
#       dtype='object')

# %%
df['TYPE'].value_counts()
# Out:
# TYPE
# FP     413
# SK      75
# FPK     28
# FPH     26
# FPM     10
# SKM      3
# SKK      3
# FPV      3
# Name: count, dtype: int64

# %%
df['PROGRAM'].value_counts()
# Out:
# PROGRAM
# AAIDS CENTER OF QUEENS COUNTY                3
# FIRST PRESBYTERIAN CHURCH OF JAMAICA         2
# IRIS HOUSE                                   2
# CHURCH OF GOD PROPHECY                       2
# ADVENT LUTHERAN CHURCH                       2
#                                             ..
# MOUNT PISGAH BAPTIST CHURCH                  1
# JESUS RECONCILIATION MINISTRIES, INC         1
# JAMAICA BENEVOLENT ARM & CULTURAL CENTER     1
# BRONX BETHANY COMMUNITY CORPORATION          1
# BETHEL AME CHURCH/BETHEL ARVERNE COMM.       1
# Name: count, Length: 514, dtype: int64

# %%
# see a list of all the value counts for the PROGRAM column
df['PROGRAM'].value_counts().index.tolist()
# Out:
# ['AAIDS CENTER OF QUEENS COUNTY ',
#  'FIRST PRESBYTERIAN CHURCH OF JAMAICA ',
#  'IRIS HOUSE ',
#  'CHURCH OF GOD PROPHECY ',
#  'ADVENT LUTHERAN CHURCH ',
#  'BROADWAY COMMUNITY ',
#  'THE SALVATION ARMY JAMAICA CITADEL CORPS ',
#  'ST. STEPHEN OUTREACH COMMUNITY DEVELOPMENT CORPORATION ',
#  'FOOD BANK FOR NEW YORK CITY ',
#  'ACTS COMMUNITY DEVELOPMENT CORPORATION ',
#  "ST. ANN'S CHURCH OF MORRISANIA ",
#  'CORONA SEVENTH DAY ADVENTIST CHURCH ',
#  'HEBRON SEVENTH DAY ADVENTIST CHURCH ',
#  ' MASBIA OF FLATBUSH ',
#  'NEW YORK COMMON PANTRY ',
#  'THE SALVATION ARMY QUEENS TEMPLE CORP ',
#  'BETHEL GOSPEL TABERNACLE CHURCH ',
#  'THE SALVATION ARMY BRONX CITADEL ',
#  'NEXT STEP COMMUNITY CHURCH ',
#  ' MASBIA OF QUEENS ',
#  'HEALTH ESSENTIAL ASSOCIATION INC ',
#  'THE SALVATION ARMY STAPLETON CORPS ',
#  'THE SALVATION ARMY SUNSET PARK CORPS ',
#  'STAPLETON U.A.M.E. CHURCH ',
#  'BETH HARK CHRISTIAN COUNSELING CENTER ',
#  'PROJECT HOSPITALITY, INC. ',
#  'FAITH CENTER FOR HUMAN SERVICES, INC ',
#  'THE SALVATION ARMY BUSHWICK CORPS ',
#  'EASTCHESTER PRESBYTERIAN CHURCH ',
#  'CORNERSTONE SEVENTH DAY ADVENTIST CHURCH ',
#  'THE URBAN OUTREACH CENTER OF NYC ',
#  'NATIONAL COUNCIL OF JEWISH WOMEN ',
#  'GRACE EPISCOPAL CHURCH ',
#  "TRINITY'S SERVICES AND FOOD FOR THE HOMELESS, INC. ",
#  'MAKE THE ROAD NEW YORK ',
#  "ISAIAH'S TEMPLE OF MT. HOPE ",
#  'CROSSROADS COMMUNITY SERVICES INC ',
#  'HOPE CENTER DEVELOPMENT CORPORATION ',
#  'MANNA OF LIFE MINISTRIES, INC ',
#  'THE RED DOOR PLACE ',
#  "THE DOOR'S FOOD & NUTRITION PROGRAM ",
#  'HOLY TABERNACLE CHURCH INC. ',
#  'UNITED METHODIST CENTER IN FAR ROCKAWAY ',
#  'PART OF THE SOLUTION ',
#  "ST. PAUL'S HOUSE INC. ",
#  'MACEDONIA AME CHURCH ',
#  'HOREB SEVENTH DAY ADVENTIST COMMUNITY SERVICES ',
#  'CATHOLIC CHARITIES ',
#  'KINGDOM GLOBAL MISSIONS ',
#  'CHURCH OF GOD OF SALVATION ',
#  "ST. PHILIP'S EPISCOPAL/ST. BENEDICT'S PANTRY ",
#  'CHANCE FOR CHILDREN ',
#  'GETHSEMANE SEVENTH DAY ADVENTIST CHURCH ',
#  'TRUE HOLY CHURCH OF GOD IN CHRIST JESUS ',
#  ' BNAI RAPHAEL CHESED ORGANIZATION INC ',
#  'LADIES IN WAITING ',
#  ' FLATBUSH COMMUNITY FUND ',
#  'GRANT HOUSE UNITY CORPORATION ',
#  'MAMRE ENRICHMENT PROGRAM ',
#  ' METROPOLITAN COUNCIL ON JEWISH POVERTY ',
#  "FERNANDE VALME' MINISTRIES INC ",
#  'CALVARY PENTECOSTAL CHURCH ',
#  'BETHANIE FRENCH SEVENTH DAY ADVENTIST CHURCH ',
#  'SANCTIFIED CHURCH OF GOD, INC/COMMUNITY FEEDING PROGRAM ',
#  'EMMAUS SEVENTH DAY ADVENTIST CHURCH ',
#  'HOLY CROSS FOOD PANTRY - BROOKLYN ',
#  'FLATBUSH SEVENTH DAY ADVENTIST CHURCH ',
#  'NEIGHBORS TOGETHER ',
#  'CHURCH OF PRAISE AND WORSHIP GOD IN CHRIST ',
#  'COMMUNITY SERVICES HOUSING DEVELOPMENT CORP. ',
#  'BROOKLYN RESCUE MISSION URBAN HARVEST CENTER INC ',
#  'BLESSED ASSURANCE CHURCH OF GOD BLESSED ASSURANCE CHARITY INC ',
#  'CENTER FOR FAMILY LIFE ',
#  'GLOVER MEMORIAL BREAD OF LIFE FOOD PANTRY ',
#  'RED HOOK COMMUNITY - REDEMPTION CHURCH ',
#  'MOVEMENT OF PENTECOSTAL CHRISTIAN CHURCH ',
#  "GOD'S DELIVERANCE TEMPLE, INC ",
#  'FOOD FIRST, INC ',
#  'GOSHEN TEMPLE OF SEVENTH DAY ADVENTIST CHURCH ',
#  'PAYO FOOD PANTRY ',
#  'OPIN ',
#  ' ICNA RELIEF QUBA PANTRY ',
#  ' COPO FOOD PANTRY ',
#  'BROOKLYN MEAL SHARE  ',
#  ' KINGS BAY Y FOOD PANTRY ',
#  "ST. MARK'S UNITED METHODIST CHURCH ",
#  'PENIEL HAITIAN CHURCH OF C AND MA ',
#  'ST. PAUL PENTECOSTAL CHURCH ',
#  'HOLY APOSTLES SOUP KITCHEN ',
#  'COLLECTIVE FOCUS FOOD JUSTICE PANTRY PROGRAM ',
#  ' SEPHARDIC BIKUR HOLIM FOOD PANTRY ',
#  'NEWMAN MEMORIAL UNITED CHURCH COMMUNITY DEVELOPMENT CORP. ',
#  'FAMILY LIFE DEVELOPMENT CENTER ',
#  'BEULAH CHURCH OF GOD IN CHRIST JESUS ',
#  'BEDFORD CENTRAL PRESBYTERIAN CHURCH ',
#  'CAMP FRIENDSHIP FOOD PANTRY IN PARK SLOPE ',
#  'AL-MADINAH SCHOOL INC ',
#  'WE CREATE COMMUNITY FOOD PANTRY ',
#  'HEALTH ESSENTIAL ASSOCIATION CPMM ',
#  ' BENSONHURST COUNCIL OF JEWISH ORGANIZATIONS ',
#  'THE CHURCH OF ST. MARK ',
#  " NAT'L COMM. FOR FUTH. OF JEWISH ED.",
#  ' CROWN HEIGHTS JEWISH COMMUNITY COUNCIL ',
#  'BETTER COMMUNITY FOOD PANTRY ',
#  'BETHANY UNITED METHODIST CHURCH ',
#  'WORLD FOR CHRIST FOOD SERVICES ',
#  'URBAN STRATEGIES INC ',
#  'PEOPLES BAPTIST CHURCH ',
#  'OUR LADY OF MERCY CHURCH ',
#  'NEW LIFE SEVENTH DAY ADVENTIST CHURCH ',
#  'MT. HEBRON CHURCH OF CHRIST ',
#  'LITTLE JERUSALEM HOUSE OF PRAYER ',
#  'EBENEZER SEVENTH DAY ADVENTIST CHURCH ',
#  'CHURCH OF GOD INC. ',
#  'BROWNSVILLE TEMPLE SEVENTH DAY ADVENTIST CHURCH ',
#  'BETHANY GOSPEL CHAPEL INC ',
#  'TRANSFIGURATION CHURCH ',
#  'SOUTHSIDE UNITED H.D.F.C., INC - LOS SURES ',
#  'TREASURES IN EARTHEN JARS FOOD PANTRY ',
#  ' MUNA SOCIAL SERVICE DOWNTOWN BROOKLYN ',
#  'NEWMAN MEMORIAL UNITED METHODIST CHURCH COMMUNITY DEVELOPMENT ',
#  'SALT & SEA MISSION CHURCH INC. ',
#  'SILOAM PRESBYTERIAN CHURCH FOOD PANTRY ',
#  ' OUR LADY OF GRACE PARISH MINISTRY ',
#  'OUR LADY OF GRACE PARISH MINISTRY ',
#  'GREENPOINT REFORMED CHURCH FOOD PANTRY ',
#  'THURSTON MEMORIAL OUTREACH MINISTRIES ',
#  "ST. JOHN'S BREAD & LIFE PROGRAM ",
#  "ST. JOHN'S BREAD & LIFE FOOD PANTRY ",
#  'OPEN DOOR FAMILY LIFE CENTER INC ',
#  'NORTHEAST BROOKLYN HOUSING DEVELOPMENT CORPORATION ',
#  ' METRO MINISTRIES INTERNATIONAL ',
#  ' CHABAD - OCEANVIEW JEWISH CENTER ',
#  'THE TABLE AT THE FAMILY SUPPORT CENTER AT NYU LANGONE ',
#  ' MUSLIMS GIVE BACK ',
#  'ACADEMY OF MEDICAL & PUBLIC HEALTH SERVICES ',
#  ' ZICHRON ACHEINU LEVY-MENACHEM TZION ',
#  ' TOMCHE SHABBOS OF BORO PARK ',
#  'PASWO ',
#  ' MUNA SOCIAL SERVICE BROOKLYN ISLAMIC CENTER ',
#  'CHRIST APOSTOLIC CHURCH GOKE FOOD PANTRY ',
#  'SOUTH BKLYN SEVENTH DAY ADVENTIST CHURCH COMMUNITY SERVICE PROGRAM ',
#  'IMMANUEL FIRST SPANISH UNITED METHODIST CHURCH ',
#  'HANSON PLACE SEVENTH DAY ADVENTIST CHURCH ',
#  'COMMUNITY HELP IN PARK SLOPE INC ',
#  'COMMUNITY HELP IN PARK SLOPE ',
#  'THE TEMPLE OF RESTORATION TTOR FOOD PANTRY ',
#  'THE SALVATION ARMY BEDFORD TEMPLE CORPS ',
#  "ST. GEORGE'S EPISCOPAL CHURCH FOOD PANTRY ",
#  "ST. GEORGE'S EPISCOPAL CHURCH ",
#  'APNA FOOD PANTRY BRIGHTON BEACH ',
#  'ST. TERESA OF AVILA ',
#  ' ICNA RELIEF USA FOOD PANTRY ',
#  'ST. TERESA OF AVILA COMMUNITY SERVICES ',
#  ' VETS INC, HOLLIS GARDENS ',
#  'QUEENSBORO TEMPLE SEVENTH DAY ADVENTIST CHURCH ',
#  'HOPE RESTORATION MINISTRIES ',
#  'HOLLIS AVENUE CONGREGATIONAL CHURCH ',
#  'DIVINE FOOD PANTRY ',
#  'MOUNT SINAI SEVENTH DAY ADVENTIST CHURCH ',
#  ' MUNA SOCIAL SERVICE MASJID AR-RAYYAN ',
#  'JESUS IS THE ANSWER - J.I.T.A. COMMUNITY OUTREACH ',
#  'HOLLIS COMMUNITY CHRISTIAN CENTER ',
#  'BERACA SEVENTH DAY ADVENTIST CHURCH ',
#  ' TAURUS ASSOCIATES INC. ',
#  'ST. PETERS - YVONNE GITTENS FOOD ',
#  'LEVITICUS CHURCH ',
#  'FIRST UNITED METHODIST CHURCH OF JAMAICA ',
#  'DELIVERANCE TEMPLE CHURCH OF JESUS CHRIST ',
#  'FAITH ASSEMBLY COMMUNITY OUTREACH ',
#  'RIVER FUND ',
#  'HOLY CHILD JESUS FOOD PANTRY ',
#  'ELOHIM CHRISTIAN CHURCH FOOD PANTRY ',
#  "CALVARY'S MISSION ",
#  ' ZION TABERNACLE F.B.H. CHURCH ',
#  ' MUNA SOCIAL SERVICE BAITUN NOOR MASJID ',
#  'THE OZONE PARK PANTRY ',
#  ' PROJECT L.E.A.D. ',
#  'OUR LADY OF GRACE MINISTRY ',
#  'VFW #5298',
#  'ALL MY CHILDREN ',
#  'JAMAICA HISPANIC SEVENTH DAY ADVENTIST CHURCH ',
#  'LINDEN SEVENTH DAY ADVENTIST CHURCH COMMUNITY SERVICES ',
#  'BLANCHE MEMORIAL CHURCH ',
#  'ST. MARY STAR OF THE SEA ',
#  'SOLID ROCK SEVENTH DAY ADVENTIST CHURCH ',
#  'QUEENS DEFENDERS NOT FOR PROFIT ',
#  ' JEWISH COMMUNITY COUNCIL OF THE ROCKAWAY PENINSULA ',
#  'J.U.S.T.I.C.E. ORGANIZATION/JESUS IS JUSTICE MISSION INC. ',
#  'FIRST PRESBYTERIAN RUSSELL SAGE MEMORIAL CHURCH OF FAR ROCKAWAY ',
#  ' MUNA SOCIAL SERVICE SOUTH JAMAICA ',
#  'UNION UNITED FOOD PANTRY ',
#  'SOUTH OZONE PARK SEVENTH DAY ADVENTIST CHURCH ',
#  'MORRIS BROWN HELPING HAND FOOD PROGRAM ',
#  ' ICNA RELIEF USA ',
#  'CHRIST APOSTOLIC CHURCH OF AMERICA, INC ',
#  'SINGH FAMILY CHARITY INC ',
#  'JAMAICA SEVENTH DAY ADVENTIST CHURCH ',
#  'NATIONAL SORORITY OF PHI DELTA KAPPA ',
#  'MORE THAN CONQUERORS GLOBAL MINISTRIES INC ',
#  'MINISTRY TOOLS INC ',
#  'MARANATHA FRENCH SEVENTH DAY ADVENTIST CHURCH ',
#  "CHRIST CHURCH INTERNATIONAL JOSEPH'S HOUSE ",
#  'THE HARDING FORD VISION, INC ',
#  'COMMUNITY CHURCH OF CHRIST FOOD PANTRY ',
#  'BETHANY BAPTIST CHURCH OF JAMAICA ',
#  'ALLEN OUTREACH MINISTRY FEEDING PROGRAM ',
#  'TABERNACLE OF PRAYER ',
#  'ST. NICHOLAS OF TOLENTINE CHURCH- F.P. ',
#  ' MASJID OMAR ABDEL AZIZ ',
#  'ONE WAY CHURCH OF CHRIST ',
#  'LEBANON SEVENTH DAY ADVENTIST CHURCH ',
#  'BAY VIEW HOUSES RESIDENT ASSOCIATION ',
#  'FOOD SHARING WITH OUR NEIGHBORS PROGRAMS ',
#  'FIRST BAPTIST CHURCH OF CORONA ',
#  'FIRST BAPTIST CHURCH ',
#  'BRIGADA DE ESPERANZA INC ',
#  'NORTHEAST CONFERENCE COMMUNITY CENTER SDA ',
#  'MT. OLIVET GOSPEL CHURCH ',
#  'IGLESIA CRISTIANA EVANGELICA ',
#  ' KEHILAT SEPHARDIM OF AHAVAT ACHIM ',
#  ' CHAZAQ ',
#  ' SAM FIELD Y ',
#  'NEW BEGINNINGS FOOD PANTRY  ',
#  'SOUTH ASIAN COUNCIL FOR SOCIAL SERVICES ',
#  ' ICNA FLUSHING FOOD PANTRY ',
#  'SISTERS WITH PURPOSE INC ',
#  'MUNA SOCIAL SERVICES - JACKSON HEIGHTS COMMUNITY FOOD BANK ',
#  'JEWISH COMMUNITY COUNCIL OF CANARSIE #1',
#  'LIFEBRIDGE NY ',
#  'CHURCH OF GOD FEEDING THE HUNGRY ',
#  'CHILD DEVELOPMENT SUPPORT CORPORATION ',
#  'BETHEL SEVENTH DAY ADVENTIST CHURCH ',
#  'CCC NEW YORK PARISH FOOD PANTRY OUTREACH PROGRAM ',
#  'REDEEMED CHRISTIAN CHURCH OF GOD INTERNATIONAL CHAPEL ',
#  'OUR LADY OF MIRACLES-CANARSIE CLUSTER CENTER ',
#  'INTERNATIONAL PENTECOSTAL CITY MISSION ',
#  ' HEBREW EDUCATIONAL SOCIETY ',
#  'CHURCH OF GOD ',
#  'CHILDREN OF THE LIGHT INTERNATIONAL MINISTRIES INC ',
#  'LOVE WINS FOOD PANTRY - MERCADITO SOLIDARIO ',
#  'ST. MARK AME CHURCH/THE VOICE OF HAGAR ',
#  'JAMAICA QUEENS WESLEYAN CHURCH PANTRY ',
#  'WOODBINE ',
#  'HOLY TEMPLE CHURCH, INC ',
#  'WORSHIP CHRISTIAN CENTER INC ',
#  'WE CARE PANTRY ',
#  'ST. ALBANS BAPTIST CHURCH ',
#  'SECOND CHANCE AGAPE WORSHIP CENTER ',
#  'MAJORITY COMMUNITY OUTREACH ',
#  'IN THE BEGINNING OUTREACH, INC ',
#  'GOSPEL ASSEMBLY - QUEENS ',
#  'FRESH ANOINTING INTERNATIONAL CHARITIES ',
#  'FIRST CHURCH OF GOD IN CHRIST, INC. ',
#  'RCA CAMBRIA HEIGHTS COMMUNITY CHURCH FP ',
#  'MORIAH CITY COMMUNITY FOOD PANTRY ',
#  'THE LEGACY CENTER COMMUNITY DEVELOPMENT CORP ',
#  'BETHANY PANTRY ',
#  'MOUNT MORIAH SEVENTH DAY ADVENTIST CHURCH FP ',
#  'COMMUNITY ALLIANCE INITIATIVE ',
#  'AGAPE CHRISTIAN CENTER ',
#  'YESHUA WORLDWIDE MINISTRIES FOOD PANTRY ',
#  'SAINT TERESA CHURCH - SAINT VINCENT DePAUL SOCIETY ',
#  'CORPUS CHRISTI FOOD PANTRY ',
#  "BVM/ST. MARY'S CHURCH WINFIELD ",
#  ' QUEENS JEWISH COMMUNITY COUNCIL ',
#  'FOREST HILLS SENIORS CENTER ',
#  ' ESTHER GRUNBLATT-CENTRAL QUEENS Y ',
#  'MINISTERIO LA LUZ DE LA ESPERANZA PARA LAS NACIONES DE JESUCRISTO ',
#  'EVANGELICAL CHURCH CHRIST IS THE LIGHT ',
#  'OUR LADY OF REFUGE R.C. CHURCH ',
#  'CITY OF REFUGE FP ',
#  'EVANGELICAL CRUSADE FOOD PANTRY ',
#  'NEW YORK CITY LOVE KITCHEN INC ',
#  ' MESIVTHA OF STATEN ISLAND ',
#  'UNITED CHURCH OF PRAISE INTERNATIONAL MINISTRIES, INC ',
#  'OUR LADY OF GOOD COUNSEL CHURCH ',
#  'FEEDING WITH TLC INC SOUP KITCHEN ',
#  'FEEDING WITH TLC INC ',
#  ' CITY HARVEST - STAPLETON MOBILE MARKET ',
#  'CHRISTIAN PENTECOSTAL CHURCH ',
#  'CHRIST ABUNDANT LIFE MINISTRIES ',
#  'REACH OUT AND TOUCH FOOD PANTRY ',
#  'COMMUNITY HEALTH ACTION OF STATEN ISLAND ',
#  'SKYLIGHT CENTER ',
#  'BAIT-UL JAMAAT-HOUSE COMMUNITY INC ',
#  'ISAACS HOLMES FOOD PANTRY ',
#  'TEMPLE SHAARAY TEFILA ',
#  'CHRIST CHURCH UNITED METHODIST ',
#  'ROOSEVELT ISLAND DISABLE ASSOCIATION (RIDA)',
#  "FATHER CREAVIN'S FOOD PANTRY ",
#  'BOROUGH COMMUNITY ACTION NETWORK HARLEM  ',
#  'ST. MARK THE EVANGELIST CHURCH ',
#  'CCCS - KENNEDY CENTER FOOD PANTRY ',
#  'BETHEL AME CHURCH ',
#  'ST. CLEMENTS FOOD PANTRY ',
#  'THE SALVATION ARMY MANHATTAN CITADEL ',
#  'FRIENDLY HANDS MINISTRY INC ',
#  'FRATERNITE NOTRE DAME, INC ',
#  'FRATERNITE NOTRE DAME ',
#  'CHAMBERS MEMORIAL BAPTIST CHURCH/LOVE OFFERING ',
#  'ST. EDWARD FOOD PANTRY ',
#  'CALVARY ASSEMBLY OF GOD ',
#  ' JEWISH COMMUNITY CENTER OF STATEN ISLAND ',
#  'ST. JEROME H.A.N.D.S. COMMUNITY CENTER ',
#  'MORRISANIA REVITALIZATION CORP INC ',
#  'INSPIRATIONAL GOSPEL ASSEMBLY ',
#  'CARING SHEPERD SUPPLIES MINISTRIES INC ',
#  'ADMIRABLE CHRIST MINISTRIES FOOD PANTRY ',
#  'WAY OUT CHURCH MINISTRIES, INC ',
#  ' UNITED BRONX PARENTS, INC. ',
#  'UNITED BRONX PARENTS, INC. ',
#  'GIVE THEM TO EAT ',
#  " CITY HARVEST - ST. MARY'S MOBILE MARKET ",
#  'CCCS BRONX FOOD PANTRY ',
#  'BRONX TEMPLE SEVENTH DAY ADVENTIST CHURCH ',
#  'ST. LUKES FOOD PANTRY ',
#  'ABRAHAM HOUSE, INC ',
#  'ABOOM! HEALTH ',
#  'ST. EDMUNDS YOUTH PROGRAM INC ',
#  ' MUNA SOCIAL SERVICE BAITUL ISLAM MASJID ',
#  'DAVIDSON COMMUNITY CENTER INC ',
#  'CALVARY UNITED METHODIST CHURCH FOOD PANTRY ',
#  'WOODYCREST UNITED METHODIST CHURCH ',
#  'WHEDCO - FOOD PANTRY ',
#  ' THE COMMUNITY FOOD PANTRY ',
#  'NEW COVENANT COMMUNITY CORP FP ',
#  'MOSAIC BEACON COMMUNITY CENTER ',
#  'AMOMENTUM PROJECT @ CHURCH OF THE GOD OF PROPHECY ',
#  'GRAND CONCOURSE SEVENTH DAY ADVENTIST CHURCH ',
#  ' CITY HARVEST - MELROSE MOBILE MARKET ',
#  'WORLDWIDE MISSIONARY MOVEMENT/CENTRO EVANGELISTICO MMM, INC ',
#  ' CITY HARVEST MOBILE MARKET - DYCKMAN HOUSES ',
#  'COMMUNITY CARE FOOD PANTRY ',
#  'CABRINI IMMIGRANT SERVICES OF NEW YORK CITY INC ',
#  'CATHEDRAL COMMUNITY CARES ',
#  'WESTSIDE CAMPAIGN AGAINST HUNGER ',
#  'ST. IGNATIUS EPISCOPAL CHURCH ',
#  " CONGREGATION B'NAI JESHURUN ",
#  ' COALITION FOR THE HOMELESS ',
#  'RAUSCHENBUSCH METRO MINISTRIES INC. ',
#  'MCCNY CHARITIES ',
#  "AGAY MEN'S HEALTH CRISIS ",
#  'GRAND CENTRAL NEIGHBORHOOD SOCIAL SERVICES CORPORATION ',
#  'GRAND CENTRAL NEIGHBORHOOD SOCIAL SERVICE CORP. ',
#  'XAVIER MISSION INC ',
#  'THE SALVATION ARMY NEW YORK TEMPLE CORPS ',
#  'THE SALVATION ARMY NEW YORK TEMPLE ',
#  "ST. PETER'S FOOD PANTRY ",
#  'ASCENSION OUTREACH, INC ',
#  'UNIVERSITY COMMUNITY SOCIAL SERVICES, INC ',
#  'THE LOWER EASTSIDE GIRLS CLUB ',
#  'THE CRW COMMUNITY FOOD PANTRY ',
#  'NAZARETH HOUSING INC ',
#  ' LILLIAN WALD FOOD PANTRY ',
#  'VISION URBANA ',
#  'UA3 COMMUNITY FIRST FOOD PANTRY',
#  'OUR LADY OF SORROWS ',
#  'MANHATTAN DOWNTOWN MULTI-CULTURAL FOOD PANTRY ',
#  'DEWITT REFORMED CHURCH ',
#  'ARTISTS ATHLETES ACTIVISTS INCORPORATED ',
#  "ST. JOHN'S BREAD OF LIFE ",
#  'CATHEDRAL OF ST. JOHN THE DIVINE ',
#  'COMMUNITY IMPACT ',
#  'SOUP KITCHEN/COMMUNITY LUNCH ',
#  'SAGE CENTER HARLEM ',
#  'BOROUGH COMMUNITY ACTION NETWORK INWOOD ',
#  ' JEWISH COMMUNITY COUNCIL OF WASHINGTON HGTS ',
#  'INTERNATIONAL PENTECOSTAL CHURCH ',
#  'CATHOLIC CHARITIES WASHINGTON HEIGHTS FOOD PANTRY ',
#  'COMMUNITY LEAGUE OF THE HEIGHTS ',
#  ' CITY HARVEST MOBILE MARKET - PRINCE HALL ',
#  'UPPER MANHATTAN MENTAL HEALTH CENTER ',
#  'FAMILY INTEGRATION MINISTRY FOOD PANTRY ',
#  'CONVENT AVENUE BAPTIST CHURCH ',
#  'ZEINA LORRAINE INC ',
#  'WEST HARLEM GROUP ASSISTANCE, INC ',
#  'ST. CHARLES BORROMEO CHURCH ',
#  "ST. CECILIA'S PARISH SERVICES ",
#  'SOUTHERN BAPTIST CHURCH ',
#  'MACEDONIA CH. ASSEMBLY OF GOD-BREAD OF LIFE FOOD PANTRY ',
#  'LITTLE SISTERS OF THE ASSUMPTION FAMILY HEALTH SERVICE ',
#  'ANOTHER CHOICE YOUTH AND FAMILY OUTREACH INC ',
#  'RIVERSIDE CHURCH FOOD PANTRY ',
#  'MT. OLIVET BAPTIST CHURCH COMMUNITY MEAL PROGRAM ',
#  'HARLEM DOWLING WEST SIDE CENTER/SPECIALIZED SERVICES ',
#  'CHURCH OF THE ANNUNCIATION ',
#  'ANTIOCH OUTREACH MINISTRIES ',
#  'AFRICAN SERVICES COMMITTEE ',
#  'PROJECT CREATE - ANTHONY HOUSE ',
#  'FREE FOOD HARLEM ',
#  "ST. MICHAEL'S CHURCH ",
#  'NEW COVENANT COMMUNITY DEVELOPMENT CORP ',
#  'REDEEMED CHRISTIAN CHURCH OF GOD ',
#  'THE BIBLE CHURCH OF CHRIST ',
#  'VINEYARD INTERNATIONAL CHRISTIAN MINISTRIES ',
#  'UNITED COMMUNITY BAPTIST CHURCH ',
#  'THE CITY OF GRACE INC ',
#  'ST. THERESE OF LISIEUX R.C. CHURCH ',
#  ' SHALOM SENIOR CENTER ',
#  'PENIEL SEVENTH DAY ADVENTIST CHURCH ',
#  ' MUNA SOCIAL SERVICE EAST FLATBUSH ',
#  'MOUNT CARMEL WORSHIP AND OUTREACH CENTER ',
#  "GOD'S BATTALION OF PRAYER CHURCH ",
#  'ELITE LEARNERS, INC ',
#  'CHRISTIAN FELLOWSHIP SEVENTH DAY ADVENTIST COMMUNITY SVCS-S.K. ',
#  'CHRISTIAN FELLOWSHIP SEVENTH DAY ADVENTIST COMMUNITY SVCS-F.P. ',
#  'BROOKLYN FAITH SEVENTH DAY ADVENTIST CHURCH ',
#  'BROOKLYN FAITH SDA CHURCH ',
#  'BEYOND WALLS, INC ',
#  'VINEGAR HILL FOOD PANTRY ',
#  'SAGE CENTER BROOKLYN ',
#  'HOUR CHILDREN COMMUNITY OUTREACH ',
#  'THE SALVATION ARMY ASTORIA CORPS ',
#  ' CITY HARVEST - ASTORIA MOBILE MARKET ',
#  'ST. RAPHAEL CHURCH FOOD PANTRY ',
#  'IGLESIA ALIANZA MISIONERA EBENEZER ',
#  'EVANGEL FOOD PANTRY ',
#  ' CITY HARVEST MOBILE MARKET - QUEENSBRIDGE HOUSES ',
#  'CENTER OF HOPE INTERNATIONAL ',
#  'COOP CITY SDA CHURCH FOOD PANTRY ',
#  'BLACK FORUM OF CO-OP CITY ',
#  'PRODIGAL CENTER ',
#  ' PAYO MOBILE FOOD PANTRY ',
#  'REACHING-OUT COMMUNITY SERVICES INC ',
#  'ST. ATHANASIUS R.C. CHURCH FP ',
#  "MYLAH'S ORGANIZATION INC  ",
#  'ADMIRABLE CHURCH INC ',
#  'OUR LADY OF ANGELS HUMAN SERVICES ',
#  'BRCDC FOOD PROGRAM ',
#  'YMCA COMMUNITY MARKET-NORTH BROOKLYN YMCA ',
#  'SECOND ST. PAUL CHURCH OF CHRIST, DISCIPLE OF CHRIST, INC ',
#  'PRESBYTERIAN CHURCH OF THE CROSSROADS ',
#  'OPEN DOOR TO HEAVEN OUTREACH MINISTRY INC ',
#  ' MUNA SOCIAL SERVICE INC ',
#  'LAS MARAVILLAS DEL EXODO ',
#  'EAST NEW YORK SEVENTH DAY ADVENTIST CHURCH ',
#  'HOLY APOSTLES SOUP KITCHEN PANTRY ',
#  'BLESSED SACRAMENT CHURCH ',
#  ' MUNA SOCIAL SERVICE AN-NAMIRAH ',
#  'CELESTIAL CHURCH OF CHRIST ILERI PARISH ',
#  'ICL AND CHN FOOD PANTRY ',
#  'HOUSE OF DAVID WORSHIP CENTER ',
#  'HOPE EMPOWERMENT AND DEVELOPMENT ZONE FOOD PANTRY ',
#  'FAMILY SERVICE NETWORK OF N.Y. INC ',
#  'EAST NEW YORK WESLEYAN CHURCH/NEW HOPE FAMILY WORSHIP CENTER ',
#  'CHRISTIAN CULTURAL CENTER ',
#  "BETHLEM NATION'S FOOD PANTRY ",
#  'TRINITY HUMAN SERVICE CORPORATION ',
#  'SOLID ROCK BAPTIST CHURCH ',
#  'SANTANA & VARGAS CHARITIES, INC ',
#  'COMPASSION HOUSE COMMUNITY DEVELOPMENT CORPORATION ',
#  ' CITY HARVEST - BED-STUY MOBILE MARKET ',
#  'CHAPEL OF THE GREAT RESTORER FOOD PANTRY ',
#  'SPANISH SOUNDVIEW SEVENTH DAY ADVENTIST CHURCH ',
#  'SHOUT FOR JOY BAPTIST CHURCH INC ',
#  'RESURRECTION AND LIFE PENTECOSTAL CHURCH ',
#  ' MUNA SOCIAL SERVICE PARKCHESTER ISLAMIC CENTER ',
#  ' JEWISH COMMUNITY COUNCIL OF PELHAM PARKWAY ',
#  "ST. PETER'S LOVE PANTRY ",
#  'GURU SEVA HIDU MILAN MANDIR CULTURAL GROUP ',
#  'UNION GROVE BAPTIST CHURCH ',
#  'ST. THOMAS AQUINAS FOOD PANTRY ',
#  "ST. ANTHONY'S CHURCH ",
#  'GETHSEMANE BAPTIST CHURCH ',
#  'WORD OF LIFE CHRISTIAN FELLOWSHIP ',
#  'THESSALONIA BAPTIST CHURCH ',
#  "ST. ANN'S CORNER OF HARM REDUCTION ",
#  'SPANISH SEVENTH DAY ADVENTIST CHURCH FOOD PANTRY ',
#  'PATHHSEO INC ',
#  'ROMAN CATHOLIC CHURCH OF ST. HELENA ',
#  'NEW YORK COMMON PANTRY - BRONX ',
#  'LOYAL BAPTIST CHURCH ',
#  'GIVE BY GRACE WHAT BY GRACE YOU HAVE RECEIVED INC ',
#  'THORPE FAMILY RESIDENCE ',
#  'THE GAMBIAN YOUTH ORGANIZATION FOOD PANTRY ',
#  'ST. SIMON STOCK FOOD PANTRY ',
#  'SAGE CENTER BRONX ',
#  'REVELACION DIVINA FOOD PANTRY  ',
#  'MORNING STAR FULL GOSPEL ASSEMBLY ',
#  'BRONX SEVENTH DAY ADVENTIST CHURCH ',
#  'ASH-SHIFAA INC FP ',
#  'WORLD RESTORATION CENTER, INC ',
#  'PARKCHESTER BAPTIST CHURCH ',
#  "ST. PAUL'S LUTHERAN CHURCH ",
#  'LT WORKS FOOD PANTRY ',
#  'POWER PRAISE AND DELIVERANCE, INC ',
#  'GRACE & PEACE FOOD BANK ',
#  'FELLOWSHIP COVENANT CHURCH ',
#  'DISCIPLES OF GALILEE, INC ',
#  'EMANUEL PENTECOSTAL FAITH CHURCH ',
#  'CHURCH OF THE ATONEMENT FOOD PANTRY ',
#  'BREAD OF LIFE FOOD PANTRY ',
#  'NORTH BRONX SEVENTH DAY ADVENTIST CHURCH ',
#  ' ICNA RELIEF BURKE AVENUE BRONX PANTRY ',
#  'GOOD NEIGHBOR COMMUNITY OUTREACH AGENCY INC ',
#  'CHURCH OF GOD OF BRONXWOOD AVENUE ',
#  'ABUNDANT GRACE FOR THE FORSAKEN FOOD PANTRY ',
#  'ST. JAMES PLACE ',
#  'HEAVENLY VISION CHRISTIAN CENTER ',
#  'THE KINGSBRIDGE HEIGHTS COMMUNITY CENTER INC ',
#  'CRESTON AVENUE BAPTIST CHURCH, INC ',
#  'CRESTON AVENUE BAPTIST CHURCH OF CHRIST, INC ',
#  'CHURCH OF ST. NICHOLAS OF TOLENTINE ',
#  'ST. BRENDAN & ST. ANN PARISH ',
#  'MOSHOLU MONTEFIORE COMMUNITY CENTER FP ',
#  'FOOD AND NUTRITION SERVICES PROGRAM ',
#  'CHRIST DISCIPLES INTERNATIONAL MINISTRIES ',
#  'UNITED YES WE CAN, UNIDOS SISE PUEDE, INC ',
#  'MOUNT PISGAH BAPTIST CHURCH ',
#  'JESUS RECONCILIATION MINISTRIES, INC ',
#  'JAMAICA BENEVOLENT ARM & CULTURAL CENTER ',
#  'BRONX BETHANY COMMUNITY CORPORATION ',
#  'BETHEL AME CHURCH/BETHEL ARVERNE COMM. ']

# %%
df['DISTADD'].value_counts().index.tolist()
# Out:
# ['108 EAST 51ST STREET',
#  '296 NINTH AVENUE',
#  '874 MYRTLE AVENUE',
#  '2290 FIRST AVENUE',
#  '5518 CHURCH AVENUE',
#  '777 SCHENECTADY AVENUE',
#  '520 50TH STREET',
#  '360 SCHERMERHORN STREET',
#  '200 FOURTH AVENUE',
#  '2348 ADAM CLAYTON POWELL JR. BLVD',
#  '110-25 GUY R. BREWER BLVD.',
#  '800 MARCY AVENUE',
#  '8 EAST 109TH STREET',
#  '89-60 164TH STREET',
#  '257 MACON STREET',
#  '71 MALTA STREET',
#  '138 PENNSYLVANIA AVE',
#  '1256 DEAN STREET',
#  '1014-18 GATES AVENUE',
#  '795 LEXINGTON AVE',
#  '1151 BUSHWICK AVENUE',
#  '1745 1ST AVENUE',
#  '1909 VYSE AVENUE',
#  '1101 BOSTON ROAD',
#  '3780 THIRD AVENUE',
#  '603 PROSPECT AVENUE',
#  '35-30 103RD STREET',
#  "295 ST. ANN'S AVENUE",
#  '100-10 ASTORIA BLVD (EAST ELMHURST)',
#  '86-07 35TH AVENUE',
#  '1372 CONEY ISLAND AVE',
#  '105-47 64TH ROAD',
#  '425 EAST 159TH STREET',
#  '114 EAST 188TH STREET',
#  '3154 FISH AVENUE',
#  '15 BROAD STREET',
#  '2114 MERMAID AVE',
#  '90-23 161ST STREET',
#  '2759 WEBSTER AVENUE',
#  '120 EAST 32ND STREET',
#  '1047 AMSTERDAM AVENUE',
#  '241 WEST 72ND STREET',
#  '1032 BEACH 19TH STREET (NEAR MOTT AVE)',
#  '602 EAST 9TH STREET',
#  '335 WEST 51ST STREET',
#  '120 WEST 14TH STREET',
#  '601 WEST 114TH STREET',
#  '2504 BROADWAY',
#  '862 GLENMORE AVE',
#  '106-16 GUY R. BREWER BLVD',
#  '555 BROOME STREET',
#  '252 WEST 116TH STREET',
#  '201 WEST 13TH STREET',
#  '443 39TH STREET',
#  '885-87 THOMAS BOYLAND STREET',
#  '27 HUNTINGTON STREET',
#  '90-92 SUMMIT STREET',
#  '167 CHESTER STREET',
#  '165 CONOVER STREET',
#  '680 MOTHER GASTON BLVD.',
#  '1045 CONEY ISLAND AVENUE',
#  '956 MARCY AVENUE',
#  '105 RIVERDALE AVENUE',
#  '634 RUGBY ROAD',
#  '2093 FULTON STREET',
#  '1323 FOSTER AVENUE',
#  '61-71 RIVERDALE AVENUE',
#  '1091 CLARKSON AVENUE',
#  '3495 NOSTRAND AVENUE',
#  '2101 EAST 16TH STREET - 2ND FLOOR',
#  '2017 BEVERLEY ROAD',
#  '2741 ALBEMARLE ROAD',
#  '2530 CHURCH AVENUE',
#  '1077 CONEY ISLAND AVENUE',
#  '447 HERZL STREET',
#  '426 DECATUR STREET',
#  '2364 ATLANTIC AVENUE',
#  '1171 EAST 95TH STREET',
#  '2085 ROCKAWAY PARKWAY',
#  '273 NEPTUNE AVENUE',
#  '3100 BRIGHTON 4TH STREET',
#  '225 NEPTUNE AVENUE',
#  '5361 PRESTON COURT',
#  '1623 UTICA AVENUE',
#  '2046 FLATBUSH AVENUE',
#  '1968 FLATBUSH AVENUE',
#  '3846 FLATLANDS AVENUE',
#  '265 DECATUR STREET',
#  '526 RALPH AVENUE',
#  '1234 EAST NEW YORK AVENUE',
#  '133 THOMAS S BOYLAND STREET',
#  '414 EAST 95TH STREET',
#  '1768 ST. JOHNS PLACE',
#  '2094 FULTON STREET',
#  '438 RALPH AVENUE',
#  '409 EAST 95TH STREET',
#  '2134 DEAN STREET',
#  '2414 CHURCH AVENUE',
#  '547 HOWARD AVE',
#  "1208 ST. JOHN'S PLACE",
#  '2059 BEDFORD AVENUE',
#  '218 BUFFALO AVENUE',
#  '1417 UNION STREET',
#  '550 59TH STREET',
#  '273 54TH STREET',
#  '5306 3RD AVENUE - 2ND FL',
#  '4518 11TH AVENUE',
#  '6225 NEW UTRECHT AVE',
#  '930 DITMAS AVENUE',
#  '722 CHURCH AVENUE',
#  '622 CORTELYOU ROAD',
#  '42 PROSPECT PLACE',
#  '424 DEAN STREET',
#  '88 HANSON PLACE',
#  '8635 21ST AVE',
#  '18 HERKIMER PLACE',
#  '601 LAFAYETTE AVENUE',
#  '2336 86TH STREET',
#  '8501 NEW UTRECHT AVENUE',
#  '260 JEFFERSON AVENUE',
#  '383 3RD AVENUE',
#  '339 8TH STREET',
#  '50 NEW YORK AVENUE',
#  '1200 DEAN STREET',
#  '1046 BROADWAY',
#  '824 EASTERN PARKWAY',
#  '261 EAST 21ST STREET',
#  '871 BUSHWICH AVENUE',
#  '1120 FLATBUSH AVE',
#  '1144 FLATBUSH AVENUE',
#  '1615 NOSTRAND AVE',
#  '151 WOODRUFF AVENUE',
#  '1476 BEDFORD AVENUE',
#  '404 LEFFERTS AVE',
#  '276 FENIMORE STREET',
#  '520 KINGSTON AVE',
#  '357 EMPIRE BLVD',
#  '11 McKEEVER PLACE - 1ST FLOOR (BASEMENT LEVEL)',
#  '2945 WEST 33RD STREET',
#  '2866 WEST 17TH STREET',
#  '425 KINGS HIGHWAY',
#  '2417-2419 STILLWELL AVE',
#  '3162 BRIGHTON 4TH STREET',
#  '2322 EAST 4TH STREET',
#  '136 MILTON STREET',
#  '1243 BUSHWICK AVE',
#  '899 MONTGOMERY STREET',
#  '999 GREEN AVENUE',
#  '627-29 REMSEN AVE',
#  '376 THROOP AVENUE',
#  '143-02 45TH AVENUE',
#  '9502 SEAVIEW AVENUE',
#  '240-08 135TH AVENUE',
#  '175-44 MAYFIELD ROAD',
#  '161-21 JAMAICA AVE - 6TH FLOOR',
#  '202-14 HOLLIS AVENUE',
#  '96-50 222ND STREET',
#  '101-01 SPRINGFIELD BLVD (QUEENS VILLAGE)',
#  '211-04 HOLLIS AVE., QUEENS VILLAGE',
#  '215-31 99TH AVENUE (QUEEN VILLAGE)',
#  '217-10 93RD AVENUE',
#  '196-43 FOOTHILL AVENUE (HOLLIS)',
#  '205-11 JAMAICA AVENUE',
#  '191-22 JAMAICA AVENUE',
#  '91-19 191 STREET',
#  '137-28 244TH STREET',
#  '88-28 161 STREET',
#  '129-04 109TH AVENUE',
#  '114-12 VAN WYCK EXPRESSWAY',
#  '134-10 ROCKAWAY BLVD SO. OZONE PARK',
#  '120-13 101ST AVENUE',
#  '89-11 LEFFERTS BLVD (RICHMOND HILL)',
#  '112-06 86TH AVENUE (RICHMOND HILL)',
#  '87-47 111TH STREET, RICHMOND HILLS',
#  '102-16 89TH AVENUE (RICHMOND HILL)',
#  '105-01 107 AVENUE (OZONE PARK)',
#  '88-19 LIBERTY AVENUE (OZONE PARK)',
#  '83-10 ROCKAWAY BLVD (OZONE PARK)',
#  '85-12 126TH STREET (KEW GARDENS)',
#  '162-10 HIGHLAND AVENUE',
#  '88-28 163 STREET',
#  '9202-14 CHURCH AVE',
#  '108-02 SUTPHIN BLVD',
#  '19-20 NEW HAVEN AVENUE',
#  '5205 ROCKAWAY BEACH BLVD',
#  '1922 MOTT AVENUE (FAR ROCKAWAY)',
#  '1525 CENTRAL AVE',
#  '223 BEACH 28TH STREET (FAR ROCKAWAY)',
#  '896 CENTRAL AVENUE (FAR ROCKAWAY)',
#  '1600 CENTRAL AVENUE - 3RD FLOOR (FAR ROCKAWAY)',
#  '164-38 108TH AVENUE',
#  '126-22 150TH STREET',
#  '120-12 140TH STREET',
#  '145-03 ROCKAWAY BLVD (SO. OZONE PARK)',
#  '8791 144TH STREET',
#  '109-74 SUTPHIN BLVD',
#  '8829 161ST STREET',
#  '121-13 SUTPHIN BLVD',
#  '117-08 MERRICK BLVD',
#  '153-56 ROCKAWAY BLVD',
#  '170-20 140TH AVE',
#  '173-04 LINDEN BLVD',
#  '122-20 MERRILL STREET',
#  '157-22 TUSKEGEE AIRMEN WAY, JAMAICA',
#  '167-04 108TH AVENUE',
#  '157-11 111TH AVE',
#  '110-31 MERRICK BLVD',
#  '90-07 MERRICK BLVD',
#  '150-75 GOETHALS AVENUE',
#  '158-10 101ST ST.- HOWARD BEACH',
#  '143-17 SPRINGFIELD BLVD',
#  '216-11 MERRICK BLVD.',
#  '242-01 BRADDOCK AVENUE (BELLROSE)',
#  '48-08 91ST PLACE (ELMHURST)',
#  '95-18 NORTHERN BLVD',
#  '35-35 71ST STREET (JACKSON HEIGHTS)',
#  '92-10 ROOSEVELT AVENUE',
#  '3763 83RD STREET - SUITE #1B (JACKSON HEIGHTS)',
#  '89-07 ASTORIA BLVD',
#  '99-13 NORTHERN BLVD',
#  '33-27 97TH STREET, CORONA',
#  '3435 96TH STREET (CORONA)',
#  '150-62 78TH ROAD (FLUSHING)',
#  '141-47 72ND AVENUE (FLUSHING)',
#  '58-25 LITTLE NECK PKWY (LITTLE NECK)',
#  '1089 CLARKSON AVE',
#  '228-20 137TH AVENUE',
#  '140-32 CHERRY AVENUE',
#  '3824 149TH STREET (FLUSHING)',
#  '1540 VAN SICLEN AVE',
#  '1170 PENNSYLVANIA AVE',
#  '560 STERLING PLACE',
#  '836 CLASSON AVE',
#  '352-358 CLASSON AVE',
#  '457 GRAND AVENUE',
#  '301 GROVE STREET',
#  '1380 JEFFERSON AVENUE',
#  '781 EAST 93RD STREET',
#  '757 EAST 86TH STREET',
#  '89-16 48TH AVENUE (ELMHURST)',
#  '79-01 BROADWAY (ELMHURST)',
#  '67-09 108TH STREET',
#  '108-25 62ND DRIVE',
#  '131-72 223RD STREET',
#  '134-49 228TH STREET (LAURELTON)',
#  '136-25 SPRINGFIELD BLVD',
#  '113-16 FARMERS BLVD',
#  '201-14 HOLLIS AVENUE',
#  '196-20 119TH AVENUE (ST. ALBANS)',
#  '200-12 HOLLIS AVENUE',
#  '115-21 FARMERS BLVD',
#  '189-13 LIBERTY AVENUE (ST. ALBANS)',
#  '109-14 FARMERS BLVD',
#  '182-10 LIBERTY AVENUE',
#  '187-10 BAISLEY BLVD',
#  '116-12 220 STREET (CAMBRIA HEIGHTS)',
#  '206-14 LINDEN BLVD (CAMBRIA HEIGHTS)',
#  '585 WOODWARD AVENUE (RIDGEWOOD)',
#  '71-02 CYPRESS HILL STREET (GLENDALE)',
#  '1834 DECATUR STREET (RIDGEWOOD)',
#  '60-85 MYRTLE AVENUE',
#  '59-02 SUMMERFIELD ST. RIDGEWOOD',
#  '7911 CALDWELL AVENUE (MIDDLE VILLAGE)',
#  '50-20 45TH STREET (WOODSIDE)',
#  '31-30 61ST STREET',
#  '70-31 48TH AVE (WOODSIDE)',
#  '62-07 WOODSIDE AVENUE - LOBBY',
#  '119-45 UNION TURNPIKE (FOREST HILLS)',
#  '1011 WINTHROP STREET',
#  '302 ELTON STREET',
#  '521 THOMAS S. BOYLAND STREET',
#  '121 GRANDVIEW AVENUE',
#  '1870 DRUMGOOLE ROAD EAST',
#  '322 NEW DORP LANE',
#  '487 VANDERBILT AVENUE',
#  '49 TOMPKINS AVENUE',
#  '49 TOMPKINS AVE',
#  '211 CANAL STREET',
#  '205 CANAL STREET',
#  '42 AUSTIN PLACE',
#  '175 BEACH STREET',
#  '309 ST. PAULS AVENUE',
#  '75 HILL STREET',
#  '900 RICHMOND ROAD',
#  '51 COTTAGE PLACE',
#  '4055 RICHMOND AVENUE',
#  '2134 RICHMOND TERRACE',
#  '307 ST. MARKS PLACE',
#  '192 CORSON AVENUE',
#  '415 EAST 93RD STREET',
#  '250 EAST 79TH STREET',
#  '524 PARK AVENUE',
#  '548A MAIN STREET (ROOSEVELT ISLAND)',
#  '276 WEST 151ST STREET',
#  '304 WEST 154TH STREET',
#  '65 WEST 138TH STREET',
#  '34 WEST 134TH STREET',
#  '54-60 WEST 132ND STREET',
#  '6581 HYLAN BOULEVARD',
#  '1466 MANOR ROAD',
#  '1140 TELLER AVE',
#  '330 EAST 138TH STREET',
#  '1001-1005 MORRIS AVENUE',
#  '1175 BOSTON ROAD',
#  '576B EAST 165TH STREET',
#  '1211 BROOK AVENUE',
#  '4056 BARNES AVENUE',
#  '1446 PROSPECT AVENUE',
#  '520 EAST 148TH STREET',
#  '800 EAST 156TH STREET',
#  '595 TRINITY AVENUE',
#  '402 EAST 152ND STREET',
#  '495 WILLIS AVENUE',
#  '623 EAST 138TH STREET',
#  '340 WILLIS AVENUE',
#  '3144 3RD AVENUE',
#  '1905 MORRIS AVENUE',
#  '2107 DAVIDSON AVENUE',
#  '2038 DAVIDSON AVENUE',
#  '1885 UNIVERSITY AVENUE',
#  '89 WEST 166TH STREET',
#  '50 EAST 168TH STREET',
#  '1363 OGDEN AVE',
#  '1240 EDWARD L. GRANT HIGHWAY',
#  '1257 OGDEN AVENUE',
#  '85 EAST 165TH STREET',
#  '1275 GRAND CONCOURSE',
#  '286 EAST 156TH STREET',
#  '423 WEST 46TH STREET 9TH/10AVE',
#  '175 EAST 125TH STREET',
#  '115 EAST 125TH STREET',
#  '55 WEST 15TH STREET',
#  '73 LENOX AVE',
#  '37 WEST 119TH STREET',
#  '225 WEST 99TH STREET',
#  '12 WEST 108TH STREET',
#  '601 WEST 114TH STREET (BASEMENT OF BROADWAY PRESBYTERIAN NY CHURCH)',
#  '616 WEST 114TH STREET',
#  '263 W. 86th St.',
#  '552 WEST END AVE',
#  '257 WEST 88TH STREET',
#  '410 WEST 40TH STREET',
#  '446 WEST 36TH STREET',
#  '307 WEST 38TH STREET',
#  '346 WEST 20TH ST. NR. 9TH AVE',
#  '219 EAST 123RD STREET',
#  '12 WEST 11TH STREET',
#  '137 EAST 2ND STREET',
#  '402 EAST 8TH STREET',
#  '25-29 AVENUE D',
#  '206 EAST 4TH STREET',
#  '12 AVENUE D',
#  '66 ESSEX STREET',
#  '384 GRAND STREET',
#  '213 STANTON STREET',
#  '160 ALLEN STREET - SUITE #20',
#  '280 RIVINGTON STREET',
#  '110 COLUMBIA STREET',
#  '(101) 429 WEST 127TH STREET',
#  '41 WEST 124TH STREET',
#  '88 CONVENT AVE. NEAR 132ND ST.',
#  '2139 ADAM CLAYTON POWELL JR. BLVD',
#  '1832 MADISON AVENUE',
#  '1832 MADISON AVE @120 ST',
#  '148 POST AVENUE',
#  '3816 9TH AVE',
#  '177 NAGLE AVENUE',
#  '630 ISHAM STREET',
#  '213 SHERMAN AVENUE',
#  '121 BENNETT AVENUE #11A',
#  '619 WEST 179TH STREET',
#  '665 WEST 182ND STREET',
#  '508 WEST 159TH STREET',
#  '454 WEST 155TH STREET',
#  '1727 AMSTERDAM AVE @ 145TH',
#  '1875 AMSTERDAM AVENUE',
#  '425 WEST 144TH STREET',
#  '203 WEST 133RD STREET',
#  '625 LENOX AVE',
#  '211 WEST 141ST STREET',
#  '220 WEST 143RD STREET',
#  '125 EAST 105TH STREET',
#  '340 EAST 106TH STREET',
#  '333 EAST 115TH STREET',
#  '1765 MADISON AVE',
#  '91 CLAREMONT AVE',
#  '201 LENOX AVE',
#  '1358 MORRIS AVENUE',
#  '488 EAST 164TH STREET',
#  '263 & 280 MARCY AVENUE',
#  '784 EAST 46TH STREET',
#  '43 GEORGE STREET',
#  '736 PARK AVENUE',
#  '138 WAVERLY AVENUE',
#  '2154 61ST STREET',
#  '6417 18TH AVENUE',
#  '2483 65TH STREET',
#  '545 UTICA AVENUE',
#  '3402 TILDEN AVENUE',
#  '4410 AVENUE D',
#  '483 ALBANY AVE',
#  '1210 UTICA AVENUE',
#  '167 EAST 43RD STREET',
#  '661 LINDEN BOULEVARD',
#  '120 TOMPKINS AVE',
#  '4517 AVENUE D',
#  '188 EAST 53RD STREET',
#  '228 YORK STREET',
#  '271 MYRTLE AVENUE (STONEWALL HOUSE)',
#  '36-49 11TH STREET (LIC)',
#  '45-18 BROADWAY',
#  '7-1 ASTORIA BLVD',
#  '35-20 GREENPOINT AVE, LIC',
#  '43-02 38TH STREET (L.I.C.)',
#  '39-21 CRESCENT STREET (LIC)',
#  '10-25 41ST AVENUE',
#  '38-49 12TH STREET (L.I.C.)',
#  '576 WILLOUGHBY AVENUE',
#  '153 A JOHNSON AVENUE',
#  '2269 CROTONA AVENUE',
#  '474 SHEPHERD AVENUE',
#  '145 SOUTH 3RD STREET',
#  '4124 AVENUE H',
#  '2020 FOSTER AVE.',
#  '1895 FLATBUSH AVENUE',
#  '557 EAST 31ST STREET',
#  '1387 EAST 37TH STREET',
#  '1910 FLATBUSH AVENUE',
#  '336 73RD STREET',
#  '9818 FORT HAMILITON PARKWAY',
#  '570 JAMAICA AVENUE',
#  '1048 SUTTER AVE',
#  '133 ELTON STREET',
#  '1033 GLENMORE AVENUE',
#  '1962-84 LINDEN BLVD',
#  '213 WEST 30TH STREET',
#  '511 ELTON STREET',
#  '1115 BLAKE AVENUE',
#  '198 EUCLID AVENUE',
#  '509 VAN SICLEN AVENUE',
#  '2135 PITKIN AVENUE',
#  '2581 ATLANTIC AVENUE',
#  '747-749-HENDRIX STREET',
#  '369 NEW LOTS AVENUE',
#  '1420 BUSHWICK AVENUE',
#  '817 LIVONIA AVENUE',
#  '12020 FLATLANDS AVENUE',
#  '1010 BAYCHESTER AVENUE',
#  '920 BAYCHESTER AVE (REAR LOBBY LEVEL)',
#  '709 TIFFANY STREET',
#  '886 WESTCHESTER AVENUE',
#  '1315 OLMSTEAD AVENUE',
#  '2021 BENEDICT AVENUE',
#  '1375 VIRGINIA AVENUE',
#  '2157 HOLLAND AVE',
#  '2500 WESTCHESTER AVENUE',
#  '3201 BRUCKNER BLVD',
#  '1488 HOE AVENUE',
#  '1900 CROTONA PARKWAY (SIDE OF CHURCH/BASEMENT)',
#  '1750 MANSION STREET',
#  '771 FAIRMOUNT PLACE',
#  '830 UNION AVENUE',
#  '951 REV. JAMES POLITE AVE',
#  '1038 PROSPECT AVENUE',
#  '1121 LONGWOOD AVENUE',
#  '870 EAST 163RD STREET',
#  '1357 SOUTHERN BLVD',
#  '1290 HOE AVENUE',
#  '881 EAST 167TH STREET',
#  '936 EAST 165TH STREET',
#  '406 EAST 184TH STREET',
#  '214 EAST 181ST STREET',
#  '2195 VALENTINE AVENUE',
#  '1784 PROSPECT AVENUE',
#  '240 EAST 175TH STREET',
#  '464 TREMONT AVENUE',
#  '1695 WASHINGTON AVENUE',
#  '1891 McGRAW AVENUE',
#  '3067 KINGSBRIDGE TERRACE',
#  '971 EAST 227TH STREET',
#  '2230 LIGHT STREET',
#  '1822 LACOMBE AVENUE',
#  '456 WHITE PLAINS ROAD',
#  '2347 LAFAYETTE AVENUE',
#  '525 COMPTON AVENUE',
#  '720 CASTLE HILL AVENUE',
#  '725 CASTLE HILL AVENUE',
#  '1310 ELDER AVE',
#  '1344 BEACH AVENUE',
#  '1104 ELDER AVENUE #15',
#  '3743 BRONXWOOD AVENUE',
#  '1277-D BURKE AVENUE',
#  '3356 SEYMOUR AVENUE',
#  '3232 LURTING AVENUE',
#  '3101 EASTCHESTER ROAD',
#  '2500 JEROME AVENUE',
#  '120 EAST 184TH STREET',
#  '2868 JEROME AVE',
#  '2345 UNIVERSITY AVE',
#  '268 EAST 207TH STREET',
#  '3450 DEKALB AVENUE',
#  '1802 CROTONA AVENUE',
#  '3021-31 WEBSTER AVENUE',
#  '4327-4331 WHITE PLAINS ROAD',
#  '709 EAST 228TH STREET',
#  '4051 BARNES AVENUE',
#  '215 BEACH 77TH STREET']

# %% [markdown]
# ## VALIDATE ZIPCODES

# %%
# chek zipcodes
df['DISTZIP'].value_counts().index.tolist()
# Out:
# [11203,
#  11207,
#  11216,
#  10456,
#  11212,
#  11432,
#  10304,
#  11208,
#  11221,
#  11233,
#  10025,
#  11226,
#  10459,
#  11691,
#  11412,
#  11433,
#  10035,
#  10452,
#  10457,
#  11236,
#  10455,
#  10469,
#  11217,
#  10011,
#  11206,
#  10009,
#  10473,
#  11230,
#  10460,
#  10002,
#  11434,
#  10468,
#  11210,
#  11413,
#  10027,
#  10029,
#  10030,
#  11372,
#  10462,
#  11213,
#  11220,
#  11101,
#  11225,
#  10034,
#  11234,
#  10466,
#  11385,
#  11429,
#  10454,
#  11375,
#  11368,
#  11238,
#  10026,
#  10451,
#  10453,
#  11423,
#  11377,
#  11223,
#  11224,
#  11418,
#  10467,
#  11369,
#  11436,
#  11218,
#  11420,
#  11214,
#  11435,
#  11231,
#  11373,
#  11235,
#  10001,
#  10037,
#  11204,
#  10018,
#  10022,
#  10128,
#  10024,
#  10031,
#  10472,
#  10033,
#  10458,
#  11211,
#  11209,
#  10302,
#  10301,
#  10039,
#  11411,
#  10032,
#  11417,
#  11239,
#  11422,
#  10023,
#  10019,
#  10016,
#  10013,
#  11355,
#  11367,
#  11219,
#  10474,
#  11237,
#  11215,
#  10309,
#  11201,
#  10475,
#  11229,
#  10461,
#  11428,
#  11419,
#  11222,
#  11354,
#  11102,
#  11103,
#  11106,
#  11453,
#  11205,
#  10463,
#  11415,
#  11416,
#  10303,
#  11414,
#  10036,
#  11232,
#  10314,
#  11379,
#  10044,
#  10065,
#  10075,
#  10312,
#  10306,
#  11362,
#  11357,
#  11692]

# %%
df['DISTZIP'] = df['DISTZIP'].astype(str).str.strip()

# %%
df[df['DISTZIP'].str.len() != 5]
# Out:
# Empty DataFrame
# Columns: [ID, TYPE, PROGRAM, PHONE, DISTADD, DISTBORO, DISTZIP, DAYS]
# Index: []

# %%
df['DISTZIP'] = df['DISTZIP'].str.split('-').str[0]

# %%
df[~df['DISTZIP'].str.isdigit()]
# Out:
# Empty DataFrame
# Columns: [ID, TYPE, PROGRAM, PHONE, DISTADD, DISTBORO, DISTZIP, DAYS]
# Index: []

# %%
df[~df['DISTZIP'].astype(int).between(10001, 11697)]
# Out:
# Empty DataFrame
# Columns: [ID, TYPE, PROGRAM, PHONE, DISTADD, DISTBORO, DISTZIP, DAYS]
# Index: []

# %%
df[['DISTZIP', 'DISTBORO']].head()
# Out:
#   DISTZIP DISTBORO
# 0   10001       NY
# 1   10001       NY
# 2   10001       NY
# 3   10002       NY
# 4   10002       NY

# %% [markdown]
# ## VALIDATE BOROS

# %%
df['DISTBORO'].value_counts()
# Out:
# DISTBORO
# BK    195
# QN    132
# BX    108
# NY    103
# SI     22
# Name: count, dtype: int64

# %%
boro_map = {
    'BK': 'Brooklyn',
    'QN': 'Queens',
    'BX': 'Bronx',
    'SI': 'Staten Island',
    'NY': 'Manhattan'
}

df['borough'] = df['DISTBORO'].map(boro_map)

# %%
df['borough'].value_counts()
# Out:
# borough
# Brooklyn         195
# Queens           132
# Bronx            108
# Manhattan        103
# Staten Island     22
# Name: count, dtype: int64

# %%
df.keys()
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'PHONE', 'DISTADD', 'DISTBORO', 'DISTZIP',
#        'DAYS', 'borough'],
#       dtype='object')

# %% [markdown]
# ### VALIDATE ID

# %%
df['ID'].duplicated().sum()
# Out:
# 0

# %%
df['ID'].is_unique
# Out:
# True

# %% [markdown]
# ### VALIDATE TYPE

# %%
df['TYPE'].value_counts()
# Out:
# TYPE
# FP     413
# SK      75
# FPK     28
# FPH     26
# FPM     10
# SKM      3
# SKK      3
# FPV      3
# Name: count, dtype: int64

# %% [markdown]
# #### Explanition of each type
# - **FP: Food pantry**
#     - People take food home such as groceries (canned goods, rice, pasta or produce)
#     - Access is weekly or monthly, is tied to hours, ID rules or residency.
#     - Think: “I need food to cook for my family this week.”
# - **SP: Soup pantry**
#     - People eat prepared meals on site which include hot meals, served same day
#     - Usually: daily or multiple times per week, fewer barriers
#     - Supports immediate hunger, especially for unhoused individuals
#     - Think: “I need a hot meal right now.
# - **FPK: Food Pantry + Kitchen**
#     - One location offers both. People can: take groceries home, eat a hot meal
#         - ✔ Pantry access
#         - ✔ Kitchen access
# - **FPH / FPM / FPV**
#     - These are pantry variants, not new service types.
#     - They still function as food pantries but differ in delivery:
#         - __FPH__ → Pantry with specific hour-based distribution
#         - __FPM__ → Mobile pantry
#         - __FPV__ → Pantry using vouchers or alternative distribution
#             - ✔ All provide take-home food
#             - ✖ No prepared meals
#     - From an access perspective, they’re still pantries.
# - **SKM / SKK**
#     - These are soup kitchen variants and different operational models
#     - Same core function: prepared meals
#         - ✔ Hot meal access
#         - ✖ No groceries
#     - From an access perspective, they’re still kitchens.
#
# We have to decide if this access distinction matters to our CRQ regarding: "Do high-priority neighborhoods have fewer food assistance options?"

# %% [markdown]
# ### Our approach
# we can do this:
# - Primary access measures:
#     - pantry access
#     - kitchen access
# - Secondary/contextual measures:
#     - weekend availability flag
#     - number of days open per week (leave this to ibrahima)
# - But we don't need to split into 5 EFAP type bins and don’t over-interpret schedule text

# %%
pantry_types = {'FP', 'FPH', 'FPM', 'FPV', 'FPK'}
kitchen_types = {'SK', 'SKM', 'SKK', 'FPK'}

# %%
df['has_pantry_access'] = df['TYPE'].isin(pantry_types).astype(int)
df['has_kitchen_access'] = df['TYPE'].isin(kitchen_types).astype(int)

# %%
df['access_type'] = (
    df['has_pantry_access'].map({1: 'Pantry', 0: ''}) +
    df['has_kitchen_access'].map({1: ' + Kitchen', 0: ''})).str.strip(' +')

# %%
df[['TYPE', 'has_pantry_access', 'has_kitchen_access', 'access_type']].head(10)
# Out:
#   TYPE  has_pantry_access  has_kitchen_access       access_type
# 0   SK                  0                   1           Kitchen
# 1   FP                  1                   0            Pantry
# 2   FP                  1                   0            Pantry
# 3   FP                  1                   0            Pantry
# 4   FP                  1                   0            Pantry
# 5   FP                  1                   0            Pantry
# 6   FP                  1                   0            Pantry
# 7   FP                  1                   0            Pantry
# 8   FP                  1                   0            Pantry
# 9  FPK                  1                   1  Pantry + Kitchen

# %% [markdown]
# ### DOCUMENTATION
# The EFAP dataset classifies food assistance sites using several administrative program type codes (e.g., FP, SK, FPK, FPH). While these codes capture operational differences across programs, they are not directly interpretable as meaningful differences in food access at the neighborhood level.
#
# To align program classifications with how residents experience food assistance, we mapped EFAP program types into two access indicators:
#
# Pantry access: whether a site provides take-home groceries
#
# Kitchen access: whether a site provides prepared meals on site
#
# Program types beginning with FP were classified as providing pantry access, program types beginning with SK were classified as providing kitchen access, and FPK sites were classified as providing both forms of access. This approach preserves the original program type codes while enabling consistent aggregation of food access options across neighborhoods.
#
# Rather than splitting EFAP sites into multiple fine-grained categories, we focus on pantry and kitchen access as baseline measures of food availability. Although operational details such as hours and distribution models meaningfully shape access, inconsistencies in schedule reporting limit our ability to model these factors reliably. As a result, our analysis captures the presence of food assistance services while acknowledging that timing and usability may further constrain access.
#
# This standardization supports neighborhood-level comparisons of food access without over-interpreting administrative subtypes that do not reflect substantively different access experiences.

# %% [markdown]
# ### Next step is asking if "this site accessible on weekdays, weekends, or both?”

# %%
df['DAYS'].value_counts().index.tolist()
# Out:
# ['THUR 10AM-12PM',
#  'SAT 10AM-12PM',
#  'WED 12-2PM',
#  'WED 10AM-12PM',
#  'SAT 12-2PM',
#  'THUR 11AM-1PM',
#  'SAT 9-11AM',
#  'THUR 12-2PM',
#  'WED 3-5PM',
#  'SAT 12-3PM',
#  'THUR 11AM-3PM',
#  'TUE 1-3PM',
#  'SAT 10AM-2PM',
#  'WED 1-3PM',
#  'TUE 11AM-1PM',
#  'SAT 9AM-1PM',
#  'SAT 10-11:30AM',
#  'FRI 12-3PM',
#  'WED 9-11AM',
#  'WED 10-11AM',
#  'SAT 10:30AM-12:30PM',
#  'THUR (1,3) 10AM-12PM',
#  'WED 10AM-1PM',
#  'SUN 10AM-12PM',
#  'SAT (2,4) 10AM-12PM',
#  'SAT 9:30AM-12PM',
#  'FRI 9AM-12PM',
#  'WED 5:30-6:30PM',
#  'SAT 10AM-1PM',
#  'SUN 12:30-2PM',
#  'TUE 9-11AM',
#  'SAT 11AM-12PM',
#  'TUE 5:30-6:30PM',
#  'WED 9:30-11AM',
#  'SAT 11AM-3PM',
#  'TUE 10AM-12PM',
#  'THUR 10-11AM',
#  'SAT 7:30-9AM',
#  'WED 12-1:30PM',
#  'SAT (2,4) 12-2PM',
#  'FRI 2-4PM',
#  'THUR 5-7PM',
#  'SAT 9-10AM',
#  'SAT 12-1:30PM',
#  'SAT 12-1PM',
#  'WED 9:30AM-12PM',
#  'TUE 9AM-12PM',
#  'SAT 11AM - 1PM',
#  'WED 5-7PM',
#  'THUR 9-11AM',
#  'SAT 1-3PM',
#  'SAT 11AM-1PM',
#  'THUR 3-5PM',
#  'SAT (4) 10AM-12PM',
#  'SAT(1,2,3,4) 11AM-1:30PM',
#  'MON-FRI 4:30-5:30PM',
#  'SAT 9-10:30AM',
#  'WED 9:30-11:30AM',
#  'TUE-FRI 9AM-1PM',
#  'SAT (1,3) 10AM-12PM',
#  'MON 9-11AM',
#  'WED,FRI 9-10:30AM',
#  'TUE (2,4) 3:30-6PM',
#  'SUN/WED 12-1PM/5-6PM',
#  'FRI 10AM-12:30PM',
#  'SAT (1,3) 12-3PM',
#  'MON 9:30AM-1:30PM (info by zip code in alpha order)',
#  'WED/FRI 6-7:15PM',
#  'TUE 10-11AM',
#  'TUE 10AM-1PM',
#  'WED/THUR 2-4PM/10AM-4PM',
#  'MON(2,4) 3-4PM',
#  'TUE/THUR 6-7:15M/11AM-2:15PM',
#  'MON-THUR 8AM-1PM',
#  'M,TU,W,TH/FRI/TU,TH 9A-12:30P/9-11A/2-3:30P',
#  'TUE,THUR,SUN 10:30AM-12:45PM',
#  'SAT(1,3) 2-4PM',
#  'TUE,WED,THUR 10AM-12PM',
#  'TUE-THUR 12:30-1:30PM',
#  'WED 12-12:30PM',
#  'M,W,THUR 9-11:30AM',
#  'SAT (1,3) 10:30AM-12PM',
#  'THUR 4-7PM',
#  'FRI 2-4:30PM',
#  'TUE,THUR/SAT (3RD) 9AM-12PM/10AM-12PM',
#  'M,TU,TH,FRI 12:30-2PM',
#  'MON,TUE,THUR 10AM-12:30PM',
#  'SAT 8:30-10:30AM',
#  'MON-THUR 10AM-12PM',
#  'MON-FRI 10:30AM-12:30PM',
#  'TUE(1,3)/SAT(2,4) 2-4PM/9AM-1PM',
#  'TUE(1,3) 12-5PM',
#  'SAT (2,4) 1-2PM',
#  'WED 10:30AM-12PM',
#  'SUN (1,3) 11AM-1PM',
#  'SAT(2,4) 6:30-7:30AM',
#  'TUE, WED 9AM-12PM',
#  'WED 10AM - 1PM',
#  'WED (2,4) 2-4PM',
#  'SAT 11AM-2:30PM',
#  'WED 9:30AM-12PM&1:30-3PM',
#  'SAT 11AM-2PM',
#  'SAT(2,4) 8-10AM',
#  'MON,FRI 9-11AM',
#  'WED (2,4) 10AM-12PM',
#  'SAT (3) 1-2PM',
#  'TUE,THUR 2-4PM',
#  'THUR 2-4PM',
#  'THUR(2,4) 11AM-2PM',
#  'TUE (2,4) 9-11AM',
#  'MON(1,3) 2-3PM',
#  'WED 10AM-1PM (info by zip code in alpha order)',
#  'WED 10:30AM-12:30PM',
#  'SAT (3RD) 12-4PM',
#  'MON/TUE/SUN 5-7PM/6-8PM/8-10AM (info by zip code in alpha order)',
#  'TUE 8-10AM',
#  'SUN(1,3) 11AM-2PM',
#  'WED(1,3) 9-10:30AM',
#  'M,TUE,WED 9-10AM',
#  'SAT (2,3,4) 9-10:30AM',
#  'TUE 1-2:45PM (info by zip code in alpha order)',
#  'THUR 1:30-5PM',
#  'MON-SAT 9-10:30AM & 11:30AM-1PM',
#  'THUR,SAT 11:30AM-1PM',
#  'THUR,THUR/SAT 10AM-4PM/10AM-1PM',
#  'FRI 10AM-3PM',
#  'TUE-THUR 12:30-2PM',
#  'MON(1,3) 4-5PM',
#  'MON 4-6PM',
#  'SAT(2,4) 10AM-12PM',
#  'TUE,THUR 10:30AM-1PM',
#  'THUR (2,4) 10:30AM-2:30PM',
#  'SAT 9AM-12PM',
#  'FRI (3RD) 12:30-2:30PM',
#  'THUR 10:30-11:30AM',
#  'TUE 10AM-4PM',
#  'FRI(1,2,3,4) 11:30AM-1:30PM',
#  'FRI 12-1PM',
#  'WED 1:30-3PM',
#  'TUE/ THUR(1ST) 12:30-2:30PM/ 5-7PM',
#  'TUE 12:30-2PM',
#  'SAT 10AM-1PM (info by zip code in alpha order)',
#  'MON 11AM-1PM',
#  'THUR 8:30-9:30AM',
#  'SAT (LAST) 2-4PM',
#  'TUE 8-11AM',
#  'FRI (1,3) 5-7:30PM',
#  'WED(1,3) 2-3PM',
#  'SAT 11-1PM',
#  'MON,THUR 9-10:30AM',
#  'WED/SAT 1-2PM/12-1PM',
#  'WED,SAT 9-11:30AM',
#  'MON, THUR 10AM-12PM',
#  'FRI 7-9AM',
#  'THUR (1,3) 4-5PM',
#  'SAT 10:30AM - 1PM',
#  'SUN 7:30-9:30AM',
#  'TUE 10:30AM-12PM',
#  'WED 2-5PM (info by zip code in alpha order)',
#  'FRI,SAT 10AM-1PM',
#  'SAT(2,4) 10:30AM-12:30PM',
#  'WED 12:30-2PM',
#  'WED-SAT 10AM -12PM',
#  'THUR 12-3PM',
#  'WED 12-3PM',
#  'SAT (4TH) 9-11AM',
#  'MON,WED 9:30-10AM',
#  'WED 1-4PM',
#  'TUE(1,2,3,4)/SAT(4) 10AM-12PM/9-11AM (info by zip code in alpha order)',
#  'SAT (1,3) 8:30-9:30AM',
#  'MON 8:30-9:30AM',
#  'TUE,THUR 9:30-11AM',
#  'TUE,FRI(1,3,5)/(2,4) 1-3PM/1-3:30PM',
#  'WED 12-1PM',
#  'TUE,THUR 9:30AM - 1:30PM',
#  'FRI 9:30-10:30AM',
#  'WED(1,3) 4-5PM',
#  'FRI(3) 12-3PM (info by zip code in alpha order)',
#  'TUE 9-10AM',
#  'SAT 8-10AM',
#  'SAT 2-4PM',
#  'THUR 4-6PM',
#  'WED/SAT 10AM-12PM/2-4PM',
#  'MON/TUE 7AM-3PM/7AM-1PM',
#  'TUE,FRI 12-2PM',
#  'TUE,WED 11AM-2PM',
#  'MON/THUR 3-5PM/11AM-1PM',
#  'MON-WED 12PM-1PM',
#  'TUE,THUR 10AM-1PM',
#  'WED 10-11:30AM',
#  'THUR 9AM-12PM',
#  'WED (3RD) 3-5PM',
#  'SUN 9:30-11:30AM',
#  'SUN 8-9AM',
#  'THUR 9AM-1PM',
#  'FRI(1) 10AM -12PM',
#  'TUE,THUR 2-3:30PM',
#  'FRI 8-11AM',
#  'SAT 12-2:30PM',
#  'M,W,F,SAT 10AM-3PM',
#  'THUR (1,2,3) 9:30AM-1:30PM',
#  'MON 12-1PM',
#  'MON (1) 10-11AM',
#  'WED 2-3PM',
#  'TUE,THUR 3-5PM',
#  'SUN (1ST) 10AM-12PM',
#  'W,THU 11AM-4PM',
#  'M,TUE,W/THU/F,SUN 10A-3:3P/10A-5P/APPT ONLY',
#  'WED 11AM-1PM',
#  'M-F/M-THUR 12-2PM/4-6PM',
#  'TUE 11AM-12PM',
#  'TUE,WED 10-11:30AM',
#  'TUE, W, THUR 1-4PM',
#  'WED/FRI 11AM-1PM/10AM-12PM',
#  'MON-THUR 3-7PM',
#  'MON-THUR 11AM-7PM',
#  'FRI 10:30AM-4:30PM',
#  'SAT 5-7PM',
#  'FRI(2) 9:30-11AM',
#  'FRI (4TH) 10AM-12PM',
#  'SAT/SAT(2ND) 10AM-12PM/1-3PM',
#  'M,W,TH/TUE/SUN 9A-2P/1-6PM/12-2PM',
#  'SUN 1-2PM',
#  'THUR,SAT 10AM-1PM',
#  'THUR (1,2,3,4) 8-11AM',
#  'TUE 4-5:30PM',
#  'WED 9-10:30AM',
#  'THUR 9:30AM-12PM',
#  'M-THUR 11AM-2PM',
#  'SUN - THUR 3-7PM (info by zip code in alpha order)',
#  'M-THUR/FR/SUN 11A-7P/10A-2P/3-7P',
#  'THUR 8:30-10:30AM',
#  'M,W/TU,TH/SUN 9A-2P&3:30-6:30P/9A-2P/10A-1:30P',
#  'FRI 9-11AM',
#  'MON-FRI 11:30AM-1PM',
#  'TUE (1,2,3,4) 12-2:45PM',
#  'THUR (1,3) 2-3PM',
#  'WED 8-10AM',
#  'FRI (4TH) 1-5PM',
#  'WED 12-1:45PM',
#  'TUE(SR ONLY)/WED 11AM-1PM/3-6PM',
#  'SUN 12-2PM',
#  'MON,WED/TUE,THUR 11AM-1PM/10AM-1PM',
#  'TUE 2:30-5PM',
#  'M,W,TH/TU/FRI 9A-2P/11A-2P/9A-12P',
#  'TUE (2ND) 10-11:30AM',
#  'WED,THUR 9:30AM-1PM',
#  'SAT 9-10AM (info by zip code in alpha order)',
#  'MON,WED 9AM-1PM',
#  'MON 12-2PM',
#  'SUN 11:30AM-1:30PM',
#  'MON-FRI 2:30-3:30PM',
#  'FRI 4-6PM',
#  'SAT(1,2,3,4) 10AM-12PM',
#  'THUR 9:30-11:30AM',
#  'FRI/SAT 2-6PM/8-11:30AM (info by zip code in alpha order)',
#  'MON-FRI 9AM-3PM',
#  'WED/THUR 10AM-12PM/10AM-12PM',
#  'FRI 2-5PM',
#  'WED,THUR 12-2PM',
#  'TUE/THUR 12-2PM/11AM - 1PM',
#  'MON-FRI 2-4PM',
#  'WED(2),SAT(4) 9:30-11:30AM',
#  'WED(1,2,3) 10AM-1PM',
#  'TUE/FRI 11:30AM-3:30PM/12-3PM',
#  'WED,SAT 9AM-1PM',
#  'THU(2),SAT(4) 9:30-11:30AM',
#  'TUE,WED,THUR 11AM-2PM',
#  'MON (1,3) 9AM-12PM',
#  'TUE,THUR 11AM-2PM',
#  'MON-THUR 10AM-2PM',
#  'SAT 9-11:30AM',
#  'WED (2ND) 3-5PM',
#  'TUE-FRI 12-1:30PM',
#  'THUR 10AM-3PM',
#  'SUN 4:30-6PM',
#  'WED 11:15AM-12PM',
#  'WED, FRI 9AM - 1PM',
#  'TUE-THUR 12-1:30PM',
#  'MON,WED,FRI 1-2PM',
#  'WED(4),SAT(2) 9:30-11:30AM',
#  'MON,WED,THUR 11AM-12:30PM',
#  'MON-FRI 9-5PM',
#  'THUR 11AM-12:30PM',
#  'FRI 10AM-1PM (info by zip code in alpha order)',
#  'WED 11AM-12PM',
#  'TUE(2ND) 10:30-11:30AM',
#  'FRI,SUN 1-3PM',
#  'MON,FRI 11:30AM-1PM',
#  'MON/WED 3-4PM/12-1PM',
#  'THUR (1,3) 11AM-3PM',
#  'TUE,FRI 10AM-1PM',
#  'TUE, THUR 11:30AM - 1PM',
#  'TUE, THUR 9-11AM',
#  'SAT 9:30-11AM',
#  'TUE(1),SAT(3) 9:30-11:30AM',
#  'TUE 2-4PM',
#  'THUR 5:30-6:30PM',
#  'SAT(1,2,4,5)/SAT(3) 12-1PM/11AM-1PM',
#  'M,TU,W,F 2:30-4:30PM',
#  'TUE 2-3PM',
#  'WED 9AM-12PM',
#  'WED-SAT 10AM-2:30PM',
#  'THUR 9AM-3PM',
#  'FRI 9-10:30AM',
#  'SAT(1,2,3,4) 11-11:30AM',
#  'TUE-THUR 11AM-2PM',
#  'WED(2) 2-3:30PM',
#  'MON-SUN 6:30-7:30A/12-1:30P/4-6P',
#  'SUN 12:45-3PM',
#  'MON-FRI 9:30-11:30AM',
#  'MON-THU 12-1PM',
#  'TUE 2-4:50PM',
#  'SAT 10:30-11:30AM',
#  'SAT(1ST,3RD) 8:30-9AM',
#  'SAT 9-10AM&1-2:30PM',
#  'MON-FRI 11AM-12PM',
#  'MON-THUR 12:30-1:30PM',
#  'WED 11:30AM-2:30PM',
#  'TUE, WED 4-5:45PM',
#  'TUE 8:30-10AM',
#  'WED 10AM-2PM',
#  'MON,THUR 10AM - 2PM',
#  'TUE,THUR 8-11AM',
#  'THUR (1st) 8:30-10:30AM',
#  'SAT(1,3) 10AM-12PM',
#  'THUR 12:30-3PM',
#  'WED (2,4) 11AM-1PM',
#  'TUE 9:30-10:30AM (info by zip code in alpha order)',
#  'MON,WED,FRI 8-:8:30AM',
#  'MON-SUN 5:30-10PM',
#  'FRI 12:30-2PM',
#  'WED 9-11:30AM & 1-2:30PM (info by zip code in alpha order)',
#  'FRI/SAT (2,4) 10-11AM/10AM-12PM',
#  'TUE,WED 10:30-11:30AM',
#  'FRI 12-2PM',
#  'TUE 2-5PM',
#  'SAT 7:30-11AM',
#  'MON-FRI 10AM-4PM',
#  'WED,FRI 5:15-7PM',
#  'MON-FRI 4-6PM',
#  'TUE,W/THUR/SAT (1) 9:30A-3:30P/12-6PM/11AM-2PM',
#  'MON,WED,THUR 11AM-2PM',
#  'THUR 10AM-1PM',
#  'SUN 10AM-3PM',
#  'THUR 12-6PM',
#  'M,TUE,W,F 10-11:30A&12:30-1:30P',
#  'TUE,THUR 2-5PM',
#  'SAT (2,4) 12-1PM',
#  'MON/SAT 6:45-7:15PM/3:45-4:15PM',
#  'THUR 12-1PM',
#  'WED/SUN 4:30-5:30PM/11:30AM-12:30PM',
#  'MON 9:30AM-1:30PM',
#  'M,W,SUN 7:30AM-8:45AM',
#  'WED(CLOSED 5TH WED)1:30-4PM',
#  'FRI 3-5PM',
#  'MON 11AM - 1PM',
#  'TUE/THUR/1ST SAT 10AM-1PM/12-3PM/10AM-12PM',
#  'THUR/SAT 10:3A-12P/1:3-3P',
#  'SAT 8AM-1PM',
#  'TUE-FRI/SAT 9AM-3PM/9-12PM',
#  'WED(1), SAT(3) 9:30-11:30AM',
#  'TUE, THUR/WED 12-3PM/11AM-2PM',
#  'WED (1,2,3,4) 5-7PM',
#  'TUE, THUR,FRI 11AM-12:45PM',
#  'TUE 11AM-2PM',
#  'SAT (2ND) 12-2PM',
#  'WED 8AM-12:30PM',
#  'SAT 8-9:30AM',
#  'THUR 10:30AM-12:30PM',
#  'SAT (1,3) 9AM-12PM',
#  'WED 9-11:30AM',
#  'WED/FRI 3-4PM/1-:2:30PM',
#  'SAT 1:30 - 4:30PM',
#  'WED/FRI 12-2PM/7-9PM',
#  'THUR 5-6PM',
#  'SAT (3RD) 10-11AM (info by zip code in alpha order)',
#  'WED/SAT 10AM-2PM',
#  'SAT (2,LAST) 9:30-10:30AM',
#  'FRI 12-4PM',
#  'TUE 9-10:30AM',
#  'THUR(3),SAT(1) 9:30-11:30AM',
#  'TUE,THUR 10AM-2PM',
#  'MON,THUR/TUE 2-4PM/10:30AM-12:30PM',
#  'FRI 1:30-2:30PM',
#  'SAT (4TH ONLY) 10AM-12PM',
#  'TUE-FRI 9AM-12PM&1-4PM',
#  'WED-FRI 11AM-1PM',
#  'MON,THUR 9AM-12PM',
#  'M-W/SAT/SUN 10AM-12:3P/12-3P/3-5P',
#  'THUR (1,3) 9-11:30AM',
#  'WED(3),SAT(1) 9:30-11:30AM',
#  'SAT (2ND) 12-3PM',
#  'MON 3:15-5PM',
#  'MON-FRI 9AM-5PM',
#  'TUE 10:30AM-12:30PM',
#  'THUR (4) 12-2PM',
#  'MON-FRI 12-1PM',
#  'FRI 10AM-12PM',
#  'MON(2,4) 5-6PM',
#  'TUE,WED,THUR 1:30-3PM',
#  'TUE,THUR 9AM-12PM',
#  'MON,TUE,WED 5-6PM (info by zip code in alpha order)',
#  'WED(1,2,3,4) 10:30AM-12:30PM',
#  'THUR 1-4PM',
#  'TUE 1:30-3PM',
#  'TUE (2,4) 12-1PM',
#  'MON,WED,FRI 12-2PM',
#  'WED (2,3,4) 10AM-12PM',
#  'WED 10AM-4PM',
#  'W,THU,F 11AM-12PM',
#  'WED/SUN (2,4) 1-4PM/3-5PM',
#  'TUE 2-6PM',
#  'TUE/THUR 2-4PM/10AM-1PM',
#  'MON,WED,FRI 9AM-1PM',
#  'WED,THUR,SAT 8AM-12PM',
#  'TUE 3:30-4:30PM',
#  'TUE 4:30-5PM',
#  'THUR (1, LAST) 4-6PM (info by zip code in alpha order)',
#  'FRI (2,4) 2-3:30PM',
#  'MON-FRI 2:30-4PM',
#  'FRI 11AM-2PM',
#  'THUR 2-5PM',
#  'TUE(4),SAT(2) 9:30-11:30AM',
#  'WED/THUR,FRI 4-6PM/10AM-12PM',
#  'M,W,THUR 11:30AM-2:30PM',
#  'FRI 10AM-1PM',
#  'SUN 11AM-1PM',
#  'WED 10AM-1PM & 5-6PM',
#  'THUR (2,4) 2-3PM',
#  'FRI 5-8PM',
#  'FRI 11AM-1PM',
#  'WED 9:30-10:30AM',
#  'M-THUR/FRI 1-5PM/2-5PM',
#  'WED 4-6PM',
#  'MON,WED/SAT 10AM-3PM/9:30AM-12:30PM',
#  'TUE 10-11:30AM',
#  'SAT(2,3) 9:30AM-11:30AM',
#  'WED(1,2,3,4)/TH(1,2,3,4) 9-11AM/3-6PM',
#  'TUE,THUR 11AM-2:30PM',
#  'FRI 8-10AM',
#  'TUE (2,4) 11AM-12PM',
#  'THUR(2,4) 4-5PM',
#  'TUE (1,3) 10AM-12PM',
#  'SAT 7AM-1PM',
#  'THUR 7:30-10:30AM',
#  'THUR 8-10AM (info by zip code in alpha order)',
#  'M-F 9AM-11PM',
#  'MON 5-7PM',
#  'THUR 8:30-11:30AM',
#  'TUE/SAT 12-2PM/10AM-12PM',
#  'THUR-SAT 10AM-2:30PM',
#  'FRI 12-1:30PM',
#  'WED 7:30-9:30AM',
#  'MON-FRI 12:30-3:30PM',
#  'MON-SAT 8:30-11AM',
#  'SUN (,4) 2-5PM',
#  'FRI 9-10AM',
#  'THUR (3) 1-3PM',
#  'MON-FRI 12-1PM & 4:30-5:30PM']

# %%
# normalize days column
df['DAYS_clean'] = df['DAYS'].str.upper()

# %% [markdown]
# Define weekday vs weekend keywords

# %%
weekday_keywords = ['MON', 'TUE', 'WED', 'THU', 'FRI']

# %%
weekend_keywords = ['SAT', 'SUN']

# %% [markdown]
# Create the flags

# %%
df['weekday_available'] = df['DAYS_clean'].str.contains(
    '|'.join(weekday_keywords),regex=True,na=False).astype(int)

# %%
df['weekend_available'] = df['DAYS_clean'].str.contains(
    '|'.join(weekend_keywords), regex=True, na=False).astype(int)

# %% [markdown]
# sanity checl

# %%
df[['DAYS', 'weekday_available', 'weekend_available']].head(15)
# Out:
#                        DAYS  weekday_available  weekend_available
# 0   MON-FRI 10:30AM-12:30PM                  1                  0
# 1     TUE,WED,THUR 1:30-3PM                  1                  0
# 2        WED (2,4) 11AM-1PM                  1                  0
# 3            THUR 12:30-3PM                  1                  0
# 4        SAT(1,3) 10AM-12PM                  0                  1
# 5   THUR (1st) 8:30-10:30AM                  1                  0
# 6           TUE,THUR 8-11AM                  1                  0
# 7       MON,THUR 10AM - 2PM                  1                  0
# 8                MON 9-11AM                  1                  0
# 9              WED 10AM-2PM                  1                  0
# 10            TUE 8:30-10AM                  1                  0
# 11        TUE, WED 4-5:45PM                  1                  0
# 12       WED 11:30AM-2:30PM                  1                  0
# 13    MON-THUR 12:30-1:30PM                  1                  0
# 14        MON-FRI 11AM-12PM                  1                  0

# %%
df[['weekday_available', 'weekend_available']].value_counts()
# Out:
# weekday_available  weekend_available
# 1                  0                    378
# 0                  1                    134
# 1                  1                     47
# 0                  0                      2
# Name: count, dtype: int64

# %% [markdown]
# ### Documentation
# We derived binary indicators for weekday and weekend availability based on the presence of day-of-week labels in reported service schedules. Given substantial variation in schedule formatting, these indicators capture whether any weekday or weekend access exists rather than modeling hours or frequency.

# %% [markdown]
# ## Now goecoding time
# I've been waiting for thissss
# ![image.png](attachment:image.png)

# %%
df.keys()
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'PHONE', 'DISTADD', 'DISTBORO', 'DISTZIP',
#        'DAYS', 'borough', 'has_pantry_access', 'has_kitchen_access',
#        'access_type', 'DAYS_clean', 'weekday_available', 'weekend_available'],
#       dtype='object')

# %% [markdown]
# ### I will investigate the addresses

# %%
df['DISTADD'].value_counts().index.tolist()
# Out:
# ['108 EAST 51ST STREET',
#  '296 NINTH AVENUE',
#  '874 MYRTLE AVENUE',
#  '2290 FIRST AVENUE',
#  '5518 CHURCH AVENUE',
#  '777 SCHENECTADY AVENUE',
#  '520 50TH STREET',
#  '360 SCHERMERHORN STREET',
#  '200 FOURTH AVENUE',
#  '2348 ADAM CLAYTON POWELL JR. BLVD',
#  '110-25 GUY R. BREWER BLVD.',
#  '800 MARCY AVENUE',
#  '8 EAST 109TH STREET',
#  '89-60 164TH STREET',
#  '257 MACON STREET',
#  '71 MALTA STREET',
#  '138 PENNSYLVANIA AVE',
#  '1256 DEAN STREET',
#  '1014-18 GATES AVENUE',
#  '795 LEXINGTON AVE',
#  '1151 BUSHWICK AVENUE',
#  '1745 1ST AVENUE',
#  '1909 VYSE AVENUE',
#  '1101 BOSTON ROAD',
#  '3780 THIRD AVENUE',
#  '603 PROSPECT AVENUE',
#  '35-30 103RD STREET',
#  "295 ST. ANN'S AVENUE",
#  '100-10 ASTORIA BLVD (EAST ELMHURST)',
#  '86-07 35TH AVENUE',
#  '1372 CONEY ISLAND AVE',
#  '105-47 64TH ROAD',
#  '425 EAST 159TH STREET',
#  '114 EAST 188TH STREET',
#  '3154 FISH AVENUE',
#  '15 BROAD STREET',
#  '2114 MERMAID AVE',
#  '90-23 161ST STREET',
#  '2759 WEBSTER AVENUE',
#  '120 EAST 32ND STREET',
#  '1047 AMSTERDAM AVENUE',
#  '241 WEST 72ND STREET',
#  '1032 BEACH 19TH STREET (NEAR MOTT AVE)',
#  '602 EAST 9TH STREET',
#  '335 WEST 51ST STREET',
#  '120 WEST 14TH STREET',
#  '601 WEST 114TH STREET',
#  '2504 BROADWAY',
#  '862 GLENMORE AVE',
#  '106-16 GUY R. BREWER BLVD',
#  '555 BROOME STREET',
#  '252 WEST 116TH STREET',
#  '201 WEST 13TH STREET',
#  '443 39TH STREET',
#  '885-87 THOMAS BOYLAND STREET',
#  '27 HUNTINGTON STREET',
#  '90-92 SUMMIT STREET',
#  '167 CHESTER STREET',
#  '165 CONOVER STREET',
#  '680 MOTHER GASTON BLVD.',
#  '1045 CONEY ISLAND AVENUE',
#  '956 MARCY AVENUE',
#  '105 RIVERDALE AVENUE',
#  '634 RUGBY ROAD',
#  '2093 FULTON STREET',
#  '1323 FOSTER AVENUE',
#  '61-71 RIVERDALE AVENUE',
#  '1091 CLARKSON AVENUE',
#  '3495 NOSTRAND AVENUE',
#  '2101 EAST 16TH STREET - 2ND FLOOR',
#  '2017 BEVERLEY ROAD',
#  '2741 ALBEMARLE ROAD',
#  '2530 CHURCH AVENUE',
#  '1077 CONEY ISLAND AVENUE',
#  '447 HERZL STREET',
#  '426 DECATUR STREET',
#  '2364 ATLANTIC AVENUE',
#  '1171 EAST 95TH STREET',
#  '2085 ROCKAWAY PARKWAY',
#  '273 NEPTUNE AVENUE',
#  '3100 BRIGHTON 4TH STREET',
#  '225 NEPTUNE AVENUE',
#  '5361 PRESTON COURT',
#  '1623 UTICA AVENUE',
#  '2046 FLATBUSH AVENUE',
#  '1968 FLATBUSH AVENUE',
#  '3846 FLATLANDS AVENUE',
#  '265 DECATUR STREET',
#  '526 RALPH AVENUE',
#  '1234 EAST NEW YORK AVENUE',
#  '133 THOMAS S BOYLAND STREET',
#  '414 EAST 95TH STREET',
#  '1768 ST. JOHNS PLACE',
#  '2094 FULTON STREET',
#  '438 RALPH AVENUE',
#  '409 EAST 95TH STREET',
#  '2134 DEAN STREET',
#  '2414 CHURCH AVENUE',
#  '547 HOWARD AVE',
#  "1208 ST. JOHN'S PLACE",
#  '2059 BEDFORD AVENUE',
#  '218 BUFFALO AVENUE',
#  '1417 UNION STREET',
#  '550 59TH STREET',
#  '273 54TH STREET',
#  '5306 3RD AVENUE - 2ND FL',
#  '4518 11TH AVENUE',
#  '6225 NEW UTRECHT AVE',
#  '930 DITMAS AVENUE',
#  '722 CHURCH AVENUE',
#  '622 CORTELYOU ROAD',
#  '42 PROSPECT PLACE',
#  '424 DEAN STREET',
#  '88 HANSON PLACE',
#  '8635 21ST AVE',
#  '18 HERKIMER PLACE',
#  '601 LAFAYETTE AVENUE',
#  '2336 86TH STREET',
#  '8501 NEW UTRECHT AVENUE',
#  '260 JEFFERSON AVENUE',
#  '383 3RD AVENUE',
#  '339 8TH STREET',
#  '50 NEW YORK AVENUE',
#  '1200 DEAN STREET',
#  '1046 BROADWAY',
#  '824 EASTERN PARKWAY',
#  '261 EAST 21ST STREET',
#  '871 BUSHWICH AVENUE',
#  '1120 FLATBUSH AVE',
#  '1144 FLATBUSH AVENUE',
#  '1615 NOSTRAND AVE',
#  '151 WOODRUFF AVENUE',
#  '1476 BEDFORD AVENUE',
#  '404 LEFFERTS AVE',
#  '276 FENIMORE STREET',
#  '520 KINGSTON AVE',
#  '357 EMPIRE BLVD',
#  '11 McKEEVER PLACE - 1ST FLOOR (BASEMENT LEVEL)',
#  '2945 WEST 33RD STREET',
#  '2866 WEST 17TH STREET',
#  '425 KINGS HIGHWAY',
#  '2417-2419 STILLWELL AVE',
#  '3162 BRIGHTON 4TH STREET',
#  '2322 EAST 4TH STREET',
#  '136 MILTON STREET',
#  '1243 BUSHWICK AVE',
#  '899 MONTGOMERY STREET',
#  '999 GREEN AVENUE',
#  '627-29 REMSEN AVE',
#  '376 THROOP AVENUE',
#  '143-02 45TH AVENUE',
#  '9502 SEAVIEW AVENUE',
#  '240-08 135TH AVENUE',
#  '175-44 MAYFIELD ROAD',
#  '161-21 JAMAICA AVE - 6TH FLOOR',
#  '202-14 HOLLIS AVENUE',
#  '96-50 222ND STREET',
#  '101-01 SPRINGFIELD BLVD (QUEENS VILLAGE)',
#  '211-04 HOLLIS AVE., QUEENS VILLAGE',
#  '215-31 99TH AVENUE (QUEEN VILLAGE)',
#  '217-10 93RD AVENUE',
#  '196-43 FOOTHILL AVENUE (HOLLIS)',
#  '205-11 JAMAICA AVENUE',
#  '191-22 JAMAICA AVENUE',
#  '91-19 191 STREET',
#  '137-28 244TH STREET',
#  '88-28 161 STREET',
#  '129-04 109TH AVENUE',
#  '114-12 VAN WYCK EXPRESSWAY',
#  '134-10 ROCKAWAY BLVD SO. OZONE PARK',
#  '120-13 101ST AVENUE',
#  '89-11 LEFFERTS BLVD (RICHMOND HILL)',
#  '112-06 86TH AVENUE (RICHMOND HILL)',
#  '87-47 111TH STREET, RICHMOND HILLS',
#  '102-16 89TH AVENUE (RICHMOND HILL)',
#  '105-01 107 AVENUE (OZONE PARK)',
#  '88-19 LIBERTY AVENUE (OZONE PARK)',
#  '83-10 ROCKAWAY BLVD (OZONE PARK)',
#  '85-12 126TH STREET (KEW GARDENS)',
#  '162-10 HIGHLAND AVENUE',
#  '88-28 163 STREET',
#  '9202-14 CHURCH AVE',
#  '108-02 SUTPHIN BLVD',
#  '19-20 NEW HAVEN AVENUE',
#  '5205 ROCKAWAY BEACH BLVD',
#  '1922 MOTT AVENUE (FAR ROCKAWAY)',
#  '1525 CENTRAL AVE',
#  '223 BEACH 28TH STREET (FAR ROCKAWAY)',
#  '896 CENTRAL AVENUE (FAR ROCKAWAY)',
#  '1600 CENTRAL AVENUE - 3RD FLOOR (FAR ROCKAWAY)',
#  '164-38 108TH AVENUE',
#  '126-22 150TH STREET',
#  '120-12 140TH STREET',
#  '145-03 ROCKAWAY BLVD (SO. OZONE PARK)',
#  '8791 144TH STREET',
#  '109-74 SUTPHIN BLVD',
#  '8829 161ST STREET',
#  '121-13 SUTPHIN BLVD',
#  '117-08 MERRICK BLVD',
#  '153-56 ROCKAWAY BLVD',
#  '170-20 140TH AVE',
#  '173-04 LINDEN BLVD',
#  '122-20 MERRILL STREET',
#  '157-22 TUSKEGEE AIRMEN WAY, JAMAICA',
#  '167-04 108TH AVENUE',
#  '157-11 111TH AVE',
#  '110-31 MERRICK BLVD',
#  '90-07 MERRICK BLVD',
#  '150-75 GOETHALS AVENUE',
#  '158-10 101ST ST.- HOWARD BEACH',
#  '143-17 SPRINGFIELD BLVD',
#  '216-11 MERRICK BLVD.',
#  '242-01 BRADDOCK AVENUE (BELLROSE)',
#  '48-08 91ST PLACE (ELMHURST)',
#  '95-18 NORTHERN BLVD',
#  '35-35 71ST STREET (JACKSON HEIGHTS)',
#  '92-10 ROOSEVELT AVENUE',
#  '3763 83RD STREET - SUITE #1B (JACKSON HEIGHTS)',
#  '89-07 ASTORIA BLVD',
#  '99-13 NORTHERN BLVD',
#  '33-27 97TH STREET, CORONA',
#  '3435 96TH STREET (CORONA)',
#  '150-62 78TH ROAD (FLUSHING)',
#  '141-47 72ND AVENUE (FLUSHING)',
#  '58-25 LITTLE NECK PKWY (LITTLE NECK)',
#  '1089 CLARKSON AVE',
#  '228-20 137TH AVENUE',
#  '140-32 CHERRY AVENUE',
#  '3824 149TH STREET (FLUSHING)',
#  '1540 VAN SICLEN AVE',
#  '1170 PENNSYLVANIA AVE',
#  '560 STERLING PLACE',
#  '836 CLASSON AVE',
#  '352-358 CLASSON AVE',
#  '457 GRAND AVENUE',
#  '301 GROVE STREET',
#  '1380 JEFFERSON AVENUE',
#  '781 EAST 93RD STREET',
#  '757 EAST 86TH STREET',
#  '89-16 48TH AVENUE (ELMHURST)',
#  '79-01 BROADWAY (ELMHURST)',
#  '67-09 108TH STREET',
#  '108-25 62ND DRIVE',
#  '131-72 223RD STREET',
#  '134-49 228TH STREET (LAURELTON)',
#  '136-25 SPRINGFIELD BLVD',
#  '113-16 FARMERS BLVD',
#  '201-14 HOLLIS AVENUE',
#  '196-20 119TH AVENUE (ST. ALBANS)',
#  '200-12 HOLLIS AVENUE',
#  '115-21 FARMERS BLVD',
#  '189-13 LIBERTY AVENUE (ST. ALBANS)',
#  '109-14 FARMERS BLVD',
#  '182-10 LIBERTY AVENUE',
#  '187-10 BAISLEY BLVD',
#  '116-12 220 STREET (CAMBRIA HEIGHTS)',
#  '206-14 LINDEN BLVD (CAMBRIA HEIGHTS)',
#  '585 WOODWARD AVENUE (RIDGEWOOD)',
#  '71-02 CYPRESS HILL STREET (GLENDALE)',
#  '1834 DECATUR STREET (RIDGEWOOD)',
#  '60-85 MYRTLE AVENUE',
#  '59-02 SUMMERFIELD ST. RIDGEWOOD',
#  '7911 CALDWELL AVENUE (MIDDLE VILLAGE)',
#  '50-20 45TH STREET (WOODSIDE)',
#  '31-30 61ST STREET',
#  '70-31 48TH AVE (WOODSIDE)',
#  '62-07 WOODSIDE AVENUE - LOBBY',
#  '119-45 UNION TURNPIKE (FOREST HILLS)',
#  '1011 WINTHROP STREET',
#  '302 ELTON STREET',
#  '521 THOMAS S. BOYLAND STREET',
#  '121 GRANDVIEW AVENUE',
#  '1870 DRUMGOOLE ROAD EAST',
#  '322 NEW DORP LANE',
#  '487 VANDERBILT AVENUE',
#  '49 TOMPKINS AVENUE',
#  '49 TOMPKINS AVE',
#  '211 CANAL STREET',
#  '205 CANAL STREET',
#  '42 AUSTIN PLACE',
#  '175 BEACH STREET',
#  '309 ST. PAULS AVENUE',
#  '75 HILL STREET',
#  '900 RICHMOND ROAD',
#  '51 COTTAGE PLACE',
#  '4055 RICHMOND AVENUE',
#  '2134 RICHMOND TERRACE',
#  '307 ST. MARKS PLACE',
#  '192 CORSON AVENUE',
#  '415 EAST 93RD STREET',
#  '250 EAST 79TH STREET',
#  '524 PARK AVENUE',
#  '548A MAIN STREET (ROOSEVELT ISLAND)',
#  '276 WEST 151ST STREET',
#  '304 WEST 154TH STREET',
#  '65 WEST 138TH STREET',
#  '34 WEST 134TH STREET',
#  '54-60 WEST 132ND STREET',
#  '6581 HYLAN BOULEVARD',
#  '1466 MANOR ROAD',
#  '1140 TELLER AVE',
#  '330 EAST 138TH STREET',
#  '1001-1005 MORRIS AVENUE',
#  '1175 BOSTON ROAD',
#  '576B EAST 165TH STREET',
#  '1211 BROOK AVENUE',
#  '4056 BARNES AVENUE',
#  '1446 PROSPECT AVENUE',
#  '520 EAST 148TH STREET',
#  '800 EAST 156TH STREET',
#  '595 TRINITY AVENUE',
#  '402 EAST 152ND STREET',
#  '495 WILLIS AVENUE',
#  '623 EAST 138TH STREET',
#  '340 WILLIS AVENUE',
#  '3144 3RD AVENUE',
#  '1905 MORRIS AVENUE',
#  '2107 DAVIDSON AVENUE',
#  '2038 DAVIDSON AVENUE',
#  '1885 UNIVERSITY AVENUE',
#  '89 WEST 166TH STREET',
#  '50 EAST 168TH STREET',
#  '1363 OGDEN AVE',
#  '1240 EDWARD L. GRANT HIGHWAY',
#  '1257 OGDEN AVENUE',
#  '85 EAST 165TH STREET',
#  '1275 GRAND CONCOURSE',
#  '286 EAST 156TH STREET',
#  '423 WEST 46TH STREET 9TH/10AVE',
#  '175 EAST 125TH STREET',
#  '115 EAST 125TH STREET',
#  '55 WEST 15TH STREET',
#  '73 LENOX AVE',
#  '37 WEST 119TH STREET',
#  '225 WEST 99TH STREET',
#  '12 WEST 108TH STREET',
#  '601 WEST 114TH STREET (BASEMENT OF BROADWAY PRESBYTERIAN NY CHURCH)',
#  '616 WEST 114TH STREET',
#  '263 W. 86th St.',
#  '552 WEST END AVE',
#  '257 WEST 88TH STREET',
#  '410 WEST 40TH STREET',
#  '446 WEST 36TH STREET',
#  '307 WEST 38TH STREET',
#  '346 WEST 20TH ST. NR. 9TH AVE',
#  '219 EAST 123RD STREET',
#  '12 WEST 11TH STREET',
#  '137 EAST 2ND STREET',
#  '402 EAST 8TH STREET',
#  '25-29 AVENUE D',
#  '206 EAST 4TH STREET',
#  '12 AVENUE D',
#  '66 ESSEX STREET',
#  '384 GRAND STREET',
#  '213 STANTON STREET',
#  '160 ALLEN STREET - SUITE #20',
#  '280 RIVINGTON STREET',
#  '110 COLUMBIA STREET',
#  '(101) 429 WEST 127TH STREET',
#  '41 WEST 124TH STREET',
#  '88 CONVENT AVE. NEAR 132ND ST.',
#  '2139 ADAM CLAYTON POWELL JR. BLVD',
#  '1832 MADISON AVENUE',
#  '1832 MADISON AVE @120 ST',
#  '148 POST AVENUE',
#  '3816 9TH AVE',
#  '177 NAGLE AVENUE',
#  '630 ISHAM STREET',
#  '213 SHERMAN AVENUE',
#  '121 BENNETT AVENUE #11A',
#  '619 WEST 179TH STREET',
#  '665 WEST 182ND STREET',
#  '508 WEST 159TH STREET',
#  '454 WEST 155TH STREET',
#  '1727 AMSTERDAM AVE @ 145TH',
#  '1875 AMSTERDAM AVENUE',
#  '425 WEST 144TH STREET',
#  '203 WEST 133RD STREET',
#  '625 LENOX AVE',
#  '211 WEST 141ST STREET',
#  '220 WEST 143RD STREET',
#  '125 EAST 105TH STREET',
#  '340 EAST 106TH STREET',
#  '333 EAST 115TH STREET',
#  '1765 MADISON AVE',
#  '91 CLAREMONT AVE',
#  '201 LENOX AVE',
#  '1358 MORRIS AVENUE',
#  '488 EAST 164TH STREET',
#  '263 & 280 MARCY AVENUE',
#  '784 EAST 46TH STREET',
#  '43 GEORGE STREET',
#  '736 PARK AVENUE',
#  '138 WAVERLY AVENUE',
#  '2154 61ST STREET',
#  '6417 18TH AVENUE',
#  '2483 65TH STREET',
#  '545 UTICA AVENUE',
#  '3402 TILDEN AVENUE',
#  '4410 AVENUE D',
#  '483 ALBANY AVE',
#  '1210 UTICA AVENUE',
#  '167 EAST 43RD STREET',
#  '661 LINDEN BOULEVARD',
#  '120 TOMPKINS AVE',
#  '4517 AVENUE D',
#  '188 EAST 53RD STREET',
#  '228 YORK STREET',
#  '271 MYRTLE AVENUE (STONEWALL HOUSE)',
#  '36-49 11TH STREET (LIC)',
#  '45-18 BROADWAY',
#  '7-1 ASTORIA BLVD',
#  '35-20 GREENPOINT AVE, LIC',
#  '43-02 38TH STREET (L.I.C.)',
#  '39-21 CRESCENT STREET (LIC)',
#  '10-25 41ST AVENUE',
#  '38-49 12TH STREET (L.I.C.)',
#  '576 WILLOUGHBY AVENUE',
#  '153 A JOHNSON AVENUE',
#  '2269 CROTONA AVENUE',
#  '474 SHEPHERD AVENUE',
#  '145 SOUTH 3RD STREET',
#  '4124 AVENUE H',
#  '2020 FOSTER AVE.',
#  '1895 FLATBUSH AVENUE',
#  '557 EAST 31ST STREET',
#  '1387 EAST 37TH STREET',
#  '1910 FLATBUSH AVENUE',
#  '336 73RD STREET',
#  '9818 FORT HAMILITON PARKWAY',
#  '570 JAMAICA AVENUE',
#  '1048 SUTTER AVE',
#  '133 ELTON STREET',
#  '1033 GLENMORE AVENUE',
#  '1962-84 LINDEN BLVD',
#  '213 WEST 30TH STREET',
#  '511 ELTON STREET',
#  '1115 BLAKE AVENUE',
#  '198 EUCLID AVENUE',
#  '509 VAN SICLEN AVENUE',
#  '2135 PITKIN AVENUE',
#  '2581 ATLANTIC AVENUE',
#  '747-749-HENDRIX STREET',
#  '369 NEW LOTS AVENUE',
#  '1420 BUSHWICK AVENUE',
#  '817 LIVONIA AVENUE',
#  '12020 FLATLANDS AVENUE',
#  '1010 BAYCHESTER AVENUE',
#  '920 BAYCHESTER AVE (REAR LOBBY LEVEL)',
#  '709 TIFFANY STREET',
#  '886 WESTCHESTER AVENUE',
#  '1315 OLMSTEAD AVENUE',
#  '2021 BENEDICT AVENUE',
#  '1375 VIRGINIA AVENUE',
#  '2157 HOLLAND AVE',
#  '2500 WESTCHESTER AVENUE',
#  '3201 BRUCKNER BLVD',
#  '1488 HOE AVENUE',
#  '1900 CROTONA PARKWAY (SIDE OF CHURCH/BASEMENT)',
#  '1750 MANSION STREET',
#  '771 FAIRMOUNT PLACE',
#  '830 UNION AVENUE',
#  '951 REV. JAMES POLITE AVE',
#  '1038 PROSPECT AVENUE',
#  '1121 LONGWOOD AVENUE',
#  '870 EAST 163RD STREET',
#  '1357 SOUTHERN BLVD',
#  '1290 HOE AVENUE',
#  '881 EAST 167TH STREET',
#  '936 EAST 165TH STREET',
#  '406 EAST 184TH STREET',
#  '214 EAST 181ST STREET',
#  '2195 VALENTINE AVENUE',
#  '1784 PROSPECT AVENUE',
#  '240 EAST 175TH STREET',
#  '464 TREMONT AVENUE',
#  '1695 WASHINGTON AVENUE',
#  '1891 McGRAW AVENUE',
#  '3067 KINGSBRIDGE TERRACE',
#  '971 EAST 227TH STREET',
#  '2230 LIGHT STREET',
#  '1822 LACOMBE AVENUE',
#  '456 WHITE PLAINS ROAD',
#  '2347 LAFAYETTE AVENUE',
#  '525 COMPTON AVENUE',
#  '720 CASTLE HILL AVENUE',
#  '725 CASTLE HILL AVENUE',
#  '1310 ELDER AVE',
#  '1344 BEACH AVENUE',
#  '1104 ELDER AVENUE #15',
#  '3743 BRONXWOOD AVENUE',
#  '1277-D BURKE AVENUE',
#  '3356 SEYMOUR AVENUE',
#  '3232 LURTING AVENUE',
#  '3101 EASTCHESTER ROAD',
#  '2500 JEROME AVENUE',
#  '120 EAST 184TH STREET',
#  '2868 JEROME AVE',
#  '2345 UNIVERSITY AVE',
#  '268 EAST 207TH STREET',
#  '3450 DEKALB AVENUE',
#  '1802 CROTONA AVENUE',
#  '3021-31 WEBSTER AVENUE',
#  '4327-4331 WHITE PLAINS ROAD',
#  '709 EAST 228TH STREET',
#  '4051 BARNES AVENUE',
#  '215 BEACH 77TH STREET']

# %%
# let's validate DISTADD
df[df['DISTADD'].isna() | (df['DISTADD'].str.strip() == '')]
# Out:
# Empty DataFrame
# Columns: [ID, TYPE, PROGRAM, PHONE, DISTADD, DISTBORO, DISTZIP, DAYS, borough, has_pantry_access, has_kitchen_access, access_type, DAYS_clean, weekday_available, weekend_available]
# Index: []

# %%
df['DISTADD'].str.contains(
    'TBD|VARIES|MULTIPLE|UNKNOWN|SEE',
    regex=True,
    na=False
).value_counts()
# Out:
# DISTADD
# False    561
# Name: count, dtype: int64

# %%
df['DISTADD'].str.contains(r'\d', regex=True).value_counts()
# Out:
# DISTADD
# True    561
# Name: count, dtype: int64

# %%
df['DISTADD'].value_counts().head(10)
# Out:
# DISTADD
# 108 EAST 51ST STREET                 3
# 296 NINTH AVENUE                     2
# 874 MYRTLE AVENUE                    2
# 2290 FIRST AVENUE                    2
# 5518 CHURCH AVENUE                   2
# 777 SCHENECTADY AVENUE               2
# 520 50TH STREET                      2
# 360 SCHERMERHORN STREET              2
# 200 FOURTH AVENUE                    2
# 2348 ADAM CLAYTON POWELL JR. BLVD    2
# Name: count, dtype: int64

# %% [markdown]
# ##### Documentation
# EFAP site street addresses were validated for completeness and geocodability, with no missing or non-address entries identified prior to spatial processing.

# %%
# build full address (geocoder-friendly)
# Create one standardized, geocoder-friendly address string and void passing fragmented fields to the APIi
df['full_address'] = (df['DISTADD'].astype(str).str.strip().str.upper()+ ', NEW YORK, NY ' + df['DISTZIP'].astype(str).str.strip())

#  Visually confirm addresses look real and consistent
df['full_address'].sample(10, random_state=42)
# Out:
# 513    215-31 99TH AVENUE (QUEEN VILLAGE), NEW YORK, ...
# 342                  424 DEAN STREET, NEW YORK, NY 11217
# 177            881 EAST 167TH STREET, NEW YORK, NY 10459
# 86               1832 MADISON AVENUE, NEW YORK, NY 10035
# 333                 257 MACON STREET, NEW YORK, NY 11216
# 140               1905 MORRIS AVENUE, NEW YORK, NY 10453
# 321                    8635 21ST AVE, NEW YORK, NY 11214
# 531                 157-11 111TH AVE, NEW YORK, NY 11433
# 101             415 EAST 93RD STREET, NEW YORK, NY 10128
# 519             175-44 MAYFIELD ROAD, NEW YORK, NY 11432
# Name: full_address, dtype: object

# %%
df[df["borough"].isna()][["DISTADD", "DISTBORO"]]
# Out:
#                                               DISTADD DISTBORO
# 47  601 WEST 114TH STREET (BASEMENT OF BROADWAY PR...      NaN

# %% [markdown]
# ##### comment
# not the basement of broadway... let me fix that

# %%
df.loc[
    df['DISTADD'].str.contains('601 WEST 114TH STREET', na=False),
    'borough'
] = 'Manhattan'

# %%
df[df["borough"].isna()][["DISTADD", "DISTBORO"]]
# Out:
# Empty DataFrame
# Columns: [DISTADD, DISTBORO]
# Index: []

# %%
df.keys()
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'PHONE', 'DISTADD', 'DISTBORO', 'DISTZIP',
#        'DAYS', 'borough', 'has_pantry_access', 'has_kitchen_access',
#        'access_type', 'DAYS_clean', 'weekday_available', 'weekend_available',
#        'full_address', 'houseNumber', 'street'],
#       dtype='object')

# %%
def geocode_geoclient(house_number, street, borough):
    params = {
        "houseNumber": str(house_number),
        "street": street,
        "borough": borough
    }

    r = requests.get(BASE_URL, headers=HEADERS, params=params)

    if r.status_code != 200:
        return pd.Series([None, None, None])

    data = r.json()

    if "address" not in data:
        return pd.Series([None, None, None])

    a = data["address"]

    return pd.Series([
        a.get("nta"),        # nta_id
        a.get("latitude"),
        a.get("longitude")
    ])

# %%
df[["nta_id", "latitude", "longitude"]] = df.apply(
    lambda r: geocode_geoclient(
        r["houseNumber"],
        r["street"],
        r["borough"]
    ),
    axis=1
)

# %% [markdown]
# ### Documentation for the 2 steps above
# - This step geocodes each EFAP site address using the NYC Geoclient API. For every record, the function sends the house number, street name, and borough to Geoclient and attempts to retrieve the corresponding Neighborhood Tabulation Area (NTA) along with latitude and longitude coordinates. If the API request fails or does not return a valid address response, the function safely returns null values rather than dropping the record. The resulting NTA identifier and coordinates are then added as new columns to the dataset, preserving all original rows while enriching the data with geographic context needed for neighborhood-level analysis.

# %%
# debug check, not needed for pipeline 
test = geocode_geoclient(df.loc[0,"houseNumber"], df.loc[0,"street"], df.loc[0,"borough"])
print(type(test))
print(test)
# Out:
# <class 'pandas.core.series.Series'>
# 0         MN13
# 1    40.749416
# 2   -73.999188
# dtype: object

# %%
# quality check
df[["nta_id", "latitude", "longitude"]].isna().mean()
# Out:
# nta_id       0.299465
# latitude     0.299465
# longitude    0.299465
# dtype: float64

# %%
# NTA distribution check
df["nta_id"].value_counts().head()
# Out:
# nta_id
# BK61    15
# BK82    14
# BK75    13
# BK42    12
# MN03    11
# Name: count, dtype: int64

# %%
df[df["nta_id"].isna()][["DISTADD", "borough"]].head()
# Out:
#                                               DISTADD    borough
# 5                        160 ALLEN STREET - SUITE #20  MANHATTAN
# 11                                     25-29 AVENUE D  MANHATTAN
# 17                      346 WEST 20TH ST. NR. 9TH AVE  MANHATTAN
# 47  601 WEST 114TH STREET (BASEMENT OF BROADWAY PR...  Manhattan
# 54                        (101) 429 WEST 127TH STREET  MANHATTAN

# %%
df.keys()
# Out:
# Index(['ID', 'TYPE', 'PROGRAM', 'PHONE', 'DISTADD', 'DISTBORO', 'DISTZIP',
#        'DAYS', 'borough', 'has_pantry_access', 'has_kitchen_access',
#        'access_type', 'DAYS_clean', 'weekday_available', 'weekend_available',
#        'full_address', 'houseNumber', 'street', 'nta_id', 'latitude',
#        'longitude'],
#       dtype='object')

# %% [markdown]
# ### DOCUMENTATION FOR GEOCODING PROCESS

# %% [markdown]
# For the EFAP dataset, the goal of this step was to assign each food assistance site to a Neighborhood Tabulation Area (NTA) and obtain geographic coordinates so the data could be analyzed at the neighborhood level. The raw EFAP data includes street address, borough, and ZIP code information, but it does not include latitude, longitude, or NTA identifiers. Because the project’s analysis is conducted at the neighborhood level, geocoding was required to translate site addresses into official NYC geographic units.
#
# To do this, NYC Geoclient was used as the geocoding service. Geoclient was chosen over general-purpose geocoders because it is maintained by the City of New York and returns authoritative NYC-specific geography, including NTA codes. This ensures higher accuracy and consistency when mapping EFAP sites to neighborhoods. A Geoclient API key was created through the NYC API Portal and stored securely as an environment variable so that credentials were not exposed in the notebook or version control.
#
# Before geocoding, address data from the EFAP dataset was prepared by separating street addresses into house number and street name components and standardizing borough values. These cleaned fields were required inputs for the Geoclient address endpoint. Once prepared, each address was sent to the Geoclient API using the house number, street, and borough as parameters.
#
# For each successful response, a subset of geographic fields was extracted from the returned data. These included latitude and longitude for spatial reference, as well as the NTA identifier, which serves as the primary neighborhood key for analysis. While Geoclient also provides additional metadata such as NTA names and census identifiers, only the NTA code was retained at this stage. NTA names are joined later from a reference table to avoid redundancy and maintain clean relational structure.
#
# Not all addresses successfully returned an NTA due to nonstandard address formats, basement descriptions, or ambiguous locations. These cases were expected and documented. Rather than dropping these rows from the dataset entirely, they were preserved in the raw EFAP data, and a geocoded analysis-ready subset was created containing only records with valid NTA identifiers and coordinates. This approach maintains data integrity while ensuring neighborhood-level analysis is performed only on reliable geographic assignments.
#
# After geocoding, validation checks were performed to assess completeness and accuracy. Missing values for NTA, latitude, and longitude were quantified, and spot checks were conducted to confirm that returned NTAs aligned with known neighborhood locations. The resulting EFAP dataset now includes reliable neighborhood identifiers and geographic coordinates and is considered complete for downstream aggregation, schema creation, and integration with NTA-level prioritization data.
#
# At this point, no further cleaning or enrichment is required for the EFAP dataset. It is ready to be used in the project’s data model and can be safely loaded during schema creation and analysis.

# %% [markdown]
# ### Further Geocoding and NTA Assignment Documentation
#
# For each EFAP site address, the NYC Geoclient API response was inspected and parsed. When a match was successful, the response returned a nested address object containing geographic metadata. From this object, latitude, longitude, and the neighborhood tabulation area identifier (nta, used as nta_id) were extracted. While additional neighborhood fields such as nta2020 were available in some responses, only the nta_id was retained for downstream analysis, as it serves as a stable neighborhood identifier and can be joined to reference tables to retrieve names or other attributes when needed.
#
# Out of 561 total EFAP records, 393 addresses were successfully geocoded, meaning they returned valid latitude, longitude, and NTA identifiers. The remaining 168 records resulted in null values for these fields. These nulls were not treated as errors, but rather as expected outcomes due to real-world address quality issues. Common causes included non-standard address formatting (such as cross-street references or basement-level descriptions), missing or ambiguous house numbers, address ranges, or location descriptions that do not correspond to a single parcel. Because the Geoclient API is intentionally strict, no attempt was made to force or infer matches for these records.
#
# All records, including those with missing geocodes, were preserved in the dataset to maintain transparency and avoid introducing bias through selective record removal. A missingness audit confirmed that approximately 29.9% of records lacked geocoded values, which is consistent with expectations for administrative and community-reported datasets. These records can either be excluded from neighborhood-level spatial analysis or revisited in future work with additional address cleaning if higher geographic coverage is required.
#
# At the conclusion of this process, the EFAP dataset contained the geographic identifiers needed for neighborhood-level analysis and was considered ready for export as a clean CSV. The dataset is now compatible with downstream steps such as schema creation, database ingestion, and joins with NTA-level tabulation or demographic datasets.

# %%
print(df.shape)
# Out:
# (561, 21)

# %%
df[["nta_id", "latitude", "longitude"]].isna().sum()
# Out:
# nta_id       168
# latitude     168
# longitude    168
# dtype: int64

# %%
df.reset_index(drop=True).shape
# Out:
# (561, 21)

# %%
# export to a clean csv
df.to_csv("efap_cleaned.csv", index=False)
